# %%
import os, sys, glob, xlrd, csv
import numpy as np

# %%
sys.path.append('/extra/InVivoDog/python/cine/tools')

# %%
sys.path.append('/extra/InVivoDog/Elazar/code_posture_onset/')

# %%
# %run "tools posture onset analysis.py"

# %%
xls_dir = './Implant_2013_10_30/'

# %%
ls -alot $xls_dir/*.xls*
# Out:
# -rw-r--r-- 1 neubauer 155136 Feb 20 11:17 ./Implant_2013_10_30//RSLNvsRRLN.Implants.10.30.13_dc_FINAL.xls
# -rw-r--r-- 1 neubauer 142336 Feb 19 11:02 ./Implant_2013_10_30//SLNvsRLN Implants 10 30 13_dc_FINAL.xls
# -rw-r--r-- 1 neubauer 141824 Feb 18 22:42 ./Implant_2013_10_30//RSLNvsRRLN Implants 10 30 13_dc_FINAL.xls
# -rw-r--r-- 1 neubauer 138240 Feb  2 10:53 ./Implant_2013_10_30//SLNvsRLN.Implants.10.30.13.xls
# -rw-r--r-- 1 neubauer 150016 Feb  2 10:53 ./Implant_2013_10_30//RSLNvsRRLN.Implants.10.30.13.xls
# -rw-r--r-- 1 neubauer 130048 Feb  2 10:52 ./Implant_2013_10_30//10 30 13 RSLNvsRRLN (2)_Latest.xls
# -rw-r--r-- 1 neubauer 137728 Feb  2 10:52 ./Implant_2013_10_30//10 30 13 SLNvsRLN Implants_Latest.xls
# -rw-r--r-- 1 neubauer 130048 Feb  1 09:51 ./Implant_2013_10_30//DONE 10 30 13 RSLNvsRRLN (2).xls
# -rw-r--r-- 1 neubauer 138240 Feb  1 09:51 ./Implant_2013_10_30//DONE SLNvsRLN Implants 10 30 13.xls
# -rw-r--r-- 1 neubauer 129024 Nov 14 22:37 ./Implant_2013_10_30//DONE 10.30.13.RSLNvsRRLN.xls
# -rw-r--r-- 1 neubauer 138752 Nov 14 22:33 ./Implant_2013_10_30//DONE SLNvsRLN.Implants.10.30.13.xls

# %%
recurrens_book = xlrd.open_workbook(filename = os.path.join(xls_dir, 'SLNvsRLN Implants 10 30 13_dc_FINAL.xls'))

vagal_book = xlrd.open_workbook(filename = os.path.join(xls_dir, 'RSLNvsRRLN.Implants.10.30.13_dc_FINAL.xls'))

# %%
show_book_content(recurrens_book)
# Out:
# work sheet info:
# #, name, #rows, #cols
# 0 GOOD No Implant (No L RLN) 74 7
# 1 GOOD Rectangle 74 7
# 2 GOOD V-Shaped 74 7
# 3 GOOD Divergent 74 7
# 4 GOOD Convergent 74 7
# 5 GOOD ELConvergent 74 7
# 6 GOOD ELRectangle 74 7
# 7 GOOD ELDivergent 74 8
# 8 GOOD-V-shape DC 74 7
# 9 GOOD EL-V Shaped 74 7

# %%
show_book_content(vagal_book)
# Out:
# work sheet info:
# #, name, #rows, #cols
# 0 GOOD ELV-shaped 74 7
# 1 GOOD V-Shaped 74 7
# 2 GOOD Rectangle 74 7
# 3 GOOD M Baseline 74 9
# 4 GOOD M Divergent 74 7
# 5 GOOD M Convergent 74 7
# 6 GOOD M ELRectangle 74 7
# 7 GOOD-ELDivergent 74 9
# 8 GOOD-ELConvergent 74 7
# 9 GOOD_No Implant 74 9
# 10 GOOD-No Implant Repeat 74 7

# %%
# 8 * 8 = (7 + 1) * (7 + 1)

Nstimulation = 64

# %%
onsettime_samples = get_onsettime_samples(workbook = recurrens_book, number_of_stimulations = Nstimulation)

# onsettime_samples = get_onsettime_samples(workbook = vagal_book, number_of_stimulations = Nstimulation)

# %%
onsettime_samples
# Out:
# {'GOOD Convergent': [23560,
#   32904,
#   33960,
#   36000,
#   44864,
#   44312,
#   36572,
#   17304,
#   24696,
#   38152,
#   49256,
#   24956,
#   45640,
#   19832,
#   28728,
#   24016,
#   47072,
#   52400,
#   45896,
#   47960,
#   39608,
#   36804,
#   24136,
#   32072,
#   26512,
#   'NP',
#   50632,
#   70976,
#   44344,
#   70688,
#   36792,
#   64176,
#   32488,
#   40140,
#   28520,
#   25906,
#   46956,
#   'NP',
#   45280,
#   'NP',
#   40376,
#   'NP',
#   29640,
#   'NP',
#   25264,
#   'NP',
#   30724,
#   72204,
#   28964,
#   'NP',
#   46744,
#   'NP',
#   43976,
#   'NP',
#   38240,
#   'NP',
#   29608,
#   'NP',
#   25680,
#   'NP',
#   26888,
#   70692,
#   28148,
#   52192],
#  'GOOD Divergent': [35888,
#   28568,
#   44624,
#   38071,
#   48976,
#   24192,
#   42904,
#   33156,
#   37144,
#   26716,
#   53180,
#   29638,
#   49695,
#   24648,
#   37488,
#   28372,
#   55432,
#   31624,
#   55128,
#   37516,
#   44416,
#   37002,
#   39880,
#   50268,
#   47636,
#   45650,
#   64964,
#   35372,
#   63440,
#   36028,
#   52096,
#   39948,
#   43268,
#   47347,
#   42540,
#   49884,
#   63488,
#   'NP',
#   66528,
#   'NP',
#   56980,
#   'NP',
#   49396,
#   66404,
#   49008,
#   50172,
#   45942,
#   52127,
#   55267,
#   'NP',
#   68984,
#   'NP',
#   65868,
#   'NP',
#   60540,
#   'NP',
#   52118,
#   'NP',
#   47520,
#   68108,
#   46228,
#   52814,
#   51102,
#   52120],
#  'GOOD EL-V Shaped': [46211,
#   47976,
#   59466,
#   61286,
#   60808,
#   49075,
#   61784,
#   58639,
#   63952,
#   47230,
#   64821,
#   57463,
#   64583,
#   60868,
#   67013,
#   66838,
#   67371,
#   59773,
#   67750,
#   60750,
#   69959,
#   68785,
#   71884,
#   74322,
#   76386,
#   'NP',
#   75857,
#   'NP',
#   74759,
#   66377,
#   74506,
#   58956,
#   70943,
#   67632,
#   71243,
#   69606,
#   64424,
#   'NP',
#   69856,
#   'NP',
#   67136,
#   'NP',
#   64491,
#   'NP',
#   65019,
#   51296,
#   69528,
#   57508,
#   60575,
#   'NP',
#   68448,
#   'NP',
#   67147,
#   'NP',
#   66562,
#   'NP',
#   57899,
#   'NP',
#   57428,
#   'NP',
#   61738,
#   50846,
#   57352,
#   50238],
#  'GOOD ELConvergent': [69172,
#   67056,
#   'NP',
#   'NP',
#   'NP',
#   64802,
#   'NP',
#   68584,
#   'NP',
#   63984,
#   'NP',
#   65394,
#   'NP',
#   70900,
#   'NP',
#   'NP',
#   'NP',
#   72104,
#   'NP',
#   70800,
#   'NP',
#   50480,
#   'NP',
#   50504,
#   66452,
#   'NP',
#   'NP',
#   'NP',
#   'NP',
#   'NP',
#   71312,
#   56124,
#   63032,
#   27896,
#   52116,
#   30800,
#   60064,
#   'NP',
#   65312,
#   'NP',
#   65448,
#   'NP',
#   55144,
#   'NP',
#   48560,
#   'NP',
#   35348,
#   58564,
#   28572,
#   'NP',
#   56480,
#   'NP',
#   53736,
#   'NP',
#   53496,
#   'NP',
#   50648,
#   'NP',
#   43872,
#   'NP',
#   43016,
#   'NP',
#   28172,
#   29128],
#  'GOOD ELDivergent': [32733,
#   34114,
#   39942,
#   38692,
#   42108,
#   38992,
#   41638,
#   41216,
#   41023,
#   37576,
#   46368,
#   39896,
#   42560,
#   36648,
#   44373,
#   38890,
#   51926,
#   48536,
#   48800,
#   51978,
#   49663,
#   49321,
#   49177,
#   54749,
#   59560,
#   61780,
#   66008,
#   63282,
#   66052,
#   64608,
#   57629,
#   66775,
#   55724,
#   73083,
#   59060,
#   75751,
#   63034,
#   77598,
#   58928,
#   77490,
#   68340,
#   77622,
#   61648,
#   77614,
#   62108,
#   77210,
#   71932,
#   77518,
#   77190,
#   '',
#   69694,
#   '',
#   73432,
#   '',
#   67768,
#   '',
#   62360,
#   '',
#   59266,
#   77148,
#   65140,
#   77228,
#   74528,
#   77132],
#  'GOOD ELRectangle': [52988,
#   54876,
#   61184,
#   60800,
#   66168,
#   56712,
#   65632,
#   63428,
#   70160,
#   56822,
#   66112,
#   62232,
#   67096,
#   69668,
#   'NP',
#   'NP',
#   69776,
#   55836,
#   73520,
#   58284,
#   76292,
#   63996,
#   71696,
#   71512,
#   76466,
#   53248,
#   76068,
#   55716,
#   76228,
#   57048,
#   'NP',
#   55328,
#   74648,
#   64504,
#   'NP',
#   67792,
#   'NP',
#   'NP',
#   'NP',
#   73608,
#   'NP',
#   73154,
#   73888,
#   54828,
#   72848,
#   53882,
#   75236,
#   55320,
#   61008,
#   'NP',
#   'NP',
#   'NP',
#   76500,
#   'NP',
#   'NP',
#   'NP',
#   61984,
#   'NP',
#   59220,
#   71906,
#   66568,
#   45478,
#   49284,
#   45049],
#  'GOOD No Implant (No L RLN)': [14598,
#   42740,
#   28848,
#   38812,
#   29500,
#   51028,
#   21208,
#   33606,
#   16940,
#   43774,
#   17156,
#   35956,
#   15266,
#   24524,
#   12104,
#   12256,
#   21464,
#   62828,
#   20160,
#   53816,
#   13960,
#   51996,
#   12832,
#   32504,
#   11756,
#   'NP',
#   23499,
#   'NP',
#   21336,
#   'NP',
#   15592,
#   62900,
#   10712,
#   45838,
#   12030,
#   18264,
#   21583,
#   'NP',
#   19300,
#   'NP',
#   17508,
#   'NP',
#   12864,
#   'NP',
#   12672,
#   'NP',
#   15717,
#   69128,
#   41812,
#   'NP',
#   20904,
#   'NP',
#   19740,
#   'NP',
#   16456,
#   'NP',
#   14672,
#   'NP',
#   10954,
#   'NP',
#   13280,
#   67320,
#   20036,
#   37584],
#  'GOOD Rectangle': [32706,
#   26128,
#   39406,
#   35156,
#   43857,
#   25704,
#   38290,
#   25256,
#   27992,
#   15853,
#   47442,
#   18498,
#   45856,
#   23626,
#   32764,
#   23163,
#   50968,
#   44980,
#   45040,
#   44027,
#   39256,
#   22036,
#   29604,
#   30845,
#   31978,
#   72684,
#   51022,
#   67908,
#   46476,
#   65038,
#   36210,
#   58404,
#   32388,
#   34066,
#   32290,
#   36732,
#   50912,
#   'NP',
#   51384,
#   'NP',
#   42418,
#   'NP',
#   32692,
#   'NP',
#   29806,
#   'NP',
#   30728,
#   47492,
#   36342,
#   'NP',
#   49344,
#   'NP',
#   45886,
#   'NP',
#   41468,
#   'NP',
#   33092,
#   'NP',
#   27508,
#   'NP',
#   32802,
#   52449,
#   33196,
#   37614],
#  'GOOD V-Shaped': [44968,
#   34292,
#   51769,
#   39314,
#   63226,
#   44170,
#   51714,
#   30909,
#   41278,
#   49036,
#   67276,
#   23056,
#   64738,
#   31208,
#   50162,
#   32670,
#   68778,
#   64166,
#   66936,
#   58096,
#   55448,
#   57376,
#   43134,
#   34150,
#   40981,
#   'NP',
#   66628,
#   'NP',
#   67809,
#   68268,
#   56595,
#   66952,
#   52353,
#   40570,
#   45045,
#   43754,
#   67374,
#   'NP',
#   65932,
#   'NP',
#   61070,
#   'NP',
#   50292,
#   'NP',
#   46664,
#   'NP',
#   44629,
#   42034,
#   45354,
#   'NP',
#   66898,
#   'NP',
#   63222,
#   'NP',
#   59046,
#   'NP',
#   53586,
#   'NP',
#   44131,
#   'NP',
#   42372,
#   56139,
#   40452,
#   43514],
#  'GOOD-V-shape DC': [44968,
#   34432,
#   51460,
#   39484,
#   62430,
#   44378,
#   55652,
#   30910,
#   41498,
#   49476,
#   67324,
#   23180,
#   64404,
#   31210,
#   49033,
#   35821,
#   67206,
#   65295,
#   65632,
#   58826,
#   54242,
#   57374,
#   20468,
#   34184,
#   40785,
#   'NP',
#   66628,
#   'NP',
#   67835,
#   68628,
#   56627,
#   67367,
#   50256,
#   40605,
#   45123,
#   43756,
#   67407,
#   'NP',
#   66584,
#   'NP',
#   60840,
#   'NP',
#   51232,
#   'NP',
#   46698,
#   'NP',
#   45530,
#   43490,
#   45604,
#   'NP',
#   66921,
#   'NP',
#   64262,
#   'NP',
#   59078,
#   'NP',
#   53612,
#   'NP',
#   44156,
#   'NP',
#   42370,
#   56399,
#   41030,
#   43518]}

# %%
nerveconditions = onsettime_samples.keys()
print nerveconditions
# Out:
# ['GOOD V-Shaped', 'GOOD Divergent', 'GOOD EL-V Shaped', 'GOOD-V-shape DC', 'GOOD Convergent', 'GOOD ELRectangle', 'GOOD No Implant (No L RLN)', 'GOOD ELConvergent', 'GOOD ELDivergent', 'GOOD Rectangle']

# %%
# copied here from the program posture_onset.implant...: TAconditions

# vagal paralysis
nerve_conditions = ["GOOD M Baseline", "GOOD_No Implant", "GOOD-No Implant Repeat",
                    "GOOD Rectangle", "GOOD M Convergent", "GOOD M Divergent", "GOOD V-Shaped",
                                        "GOOD M ELRectangle", "GOOD-ELConvergent", "GOOD-ELDivergent", "GOOD ELV-shaped"]

# recurrent nerve paralysis
# nerve_conditions = ['GOOD No Implant (No L RLN)', 'GOOD Rectangle', 'GOOD Convergent', 'GOOD Divergent',
#                     'GOOD-V-shape DC', 'GOOD ELRectangle', 'GOOD ELConvergent', 'GOOD ELDivergent', 'GOOD EL-V Shaped']

# %%
# compare to available cines in cine directory
# !ls -alot /extra/InVivoDog/InVivoDog_2013_10_30/SLN\ versus\ RLN

# !ls -alot /extra/InVivoDog/InVivoDog_2013_10_30/right\ SLN\ versus\ right\ RLN
# Out:
# total 0
# drwxr-xr-x 1 neubauer 260 Nov 14 23:07 ..
# drwxr-xr-x 1 neubauer   0 Oct 31 01:07 baseline
# drwxr-xr-x 1 neubauer  16 Oct 30 19:02 .
# total 0
# drwxr-xr-x 1 neubauer 260 Nov 14 23:07 ..
# drwxr-xr-x 1 neubauer   0 Oct 31 05:43 V-shaped implant
# drwxr-xr-x 1 neubauer 410 Oct 31 03:50 .
# drwxr-xr-x 1 neubauer   0 Oct 31 03:50 rectangular implant
# drwxr-xr-x 1 neubauer   0 Oct 31 03:49 no implant baseline repeat
# drwxr-xr-x 1 neubauer   0 Oct 31 03:47 long V-shaped implant
# drwxr-xr-x 1 neubauer   0 Oct 31 03:43 long rectangular implant
# drwxr-xr-x 1 neubauer   0 Oct 31 00:38 long divergent implant
# drwxr-xr-x 1 neubauer   0 Oct 31 00:36 long convergent implant
# drwxr-xr-x 1 neubauer   0 Oct 31 00:34 divergent implant
# drwxr-xr-x 1 neubauer   0 Oct 31 00:32 convergent implant
# drwxr-xr-x 1 neubauer   0 Oct 30 21:23 baseline no implant

# %%
dd = OrderedDict([(nervecondition, 
                   dict(onsettime_samples = onsettime_samples[nervecondition], 
                        cinefiledir = None)) 
             for nervecondition in nerveconditions])

# %%
dd['GOOD M Baseline']['cinefiledir'] = ['SLN versus RLN', 'baseline02']

# %%
videosTAconditions = [["SLN versus RLN", "baseline02"],
                                  "baseline no implant", "no implant baseline repeat", 
                                  "rectangular implant", "convergent implant",
                                  "divergent implant", "V-shaped implant",
                                  "long rectangular implant", "long convergent implant",
                                  "long divergent implant", "long V-shaped implant"]

# %%
combined = zip(nerve_conditions, videosTAconditions)
print combined
# Out:
# [('GOOD M Baseline', ['SLN versus RLN', 'baseline02']), ('GOOD_No Implant', 'baseline no implant'), ('GOOD-No Implant Repeat', 'no implant baseline repeat'), ('GOOD Rectangle', 'rectangular implant'), ('GOOD M Convergent', 'convergent implant'), ('GOOD M Divergent', 'divergent implant'), ('GOOD V-Shaped', 'V-shaped implant'), ('GOOD M ELRectangle', 'long rectangular implant'), ('GOOD-ELConvergent', 'long convergent implant'), ('GOOD-ELDivergent', 'long divergent implant'), ('GOOD ELV-shaped', 'long V-shaped implant')]

# %%
from collections import OrderedDict

# %%
OrderedDict(combined).values()
# Out:
# [['SLN versus RLN', 'baseline02'],
#  'baseline no implant',
#  'no implant baseline repeat',
#  'rectangular implant',
#  'convergent implant',
#  'divergent implant',
#  'V-shaped implant',
#  'long rectangular implant',
#  'long convergent implant',
#  'long divergent implant',
#  'long V-shaped implant']

# %%
dd = OrderedDict([(nervecondition, 
                   dict(onsettime_samples = onsettime_samples[nervecondition], 
                        cinefiledir = videosTAconditions[num])) 
             for num, nervecondition in enumerate(nerve_conditions)])

# %%
for key in dd.keys():
    print "{}: {}".format(key, dd[key]['cinefiledir'])
    print dd[key]['onsettime_samples']
# Out:
# GOOD M Baseline: ['SLN versus RLN', 'baseline02']
# [19176, 54192, 25100, 17580, 33456, 66684, 24056, 23328, 15888, 66264, 13599, 34312, 30342, 12846, 21560, 13536, 16800, 'NP', 30294, 'NP', 21659, 48848, 16352, 21044, 13416, 'NP', 30322, 'NP', 27480, 'NP', 24114, 46968, 18440, 23452, 14244, 12187, 27264, 'NP', 25792, 'NP', 22242, 'NP', 18684, 'NP', 15967, 68792, 13544, 24896, 12152, 'NP', 24888, 'NP', 23298, 'NP', 19708, 'NP', 15414, 'NP', 16360, 65014, 11150, 21350, 15452, 16358]
# GOOD_No Implant: baseline no implant
# [11784, 43142, 27326, 27600, 23874, 46354, 18110, 27880, 8481, 34656, 13599, 18296, 15104, 13512, 12006, 8482, 16800, 33744, 16368, 24843, 12832, 15132, 12580, 10520, 12770, 28479, 16896, 28904, 16290, 21446, 14649, 12490, 12312, 11915, 11904, 12187, 17115, 32124, 15482, 29625, 15337, 28344, 11434, 20405, 11420, 13050, 11280, 11448, 11548, 38552, 14819, 35848, 14687, 33108, 14732, 27228, 12999, 17944, 11599, 12652, 11150, 13444, 10424, 11934]
# GOOD-No Implant Repeat: no implant baseline repeat
# [33702, 39798, 35860, 36706, 21368, 51550, 26322, 39552, 22680, 45162, 10334, 31784, 15004, 20737, 9976, 9460, 10360, 47065, 11889, 41961, 12148, 24206, 11256, 13716, 12336, 44437, 13763, 37637, 14050, 27204, 12896, 16768, 13136, 8353, 12684, 12680, 13588, 47700, 14604, 40942, 13935, 39488, 10586, 22730, 10789, 13444, 13180, 11182, 12473, 47825, 14150, 44464, 15108, 43600, 13620, 30272, 10214, 16986, 11612, 10021, 11490, 12285, 10336, 11913]
# GOOD Rectangle: rectangular implant
# [33768, 44940, 45900, 44892, 37950, 52312, 35554, 34238, 22284, 42048, 38312, 32768, 36020, 23038, 28284, 20740, 40628, 39056, 38028, 29644, 30506, 19828, 25384, 20798, 24068, 33460, 41952, 32984, 38828, 29624, 33386, 17808, 27164, 21786, 25498, 22392, 38568, 34384, 38060, 35848, 32868, 32032, 25970, 21372, 25908, 22606, 23491, 25941, 23841, 34305, 39996, 35748, 36530, 33020, 32732, 29246, 25778, 20446, 23530, 25368, 22026, 22384, 21726, 21030]
# GOOD M Convergent: convergent implant
# [27844, 48512, 44944, 47936, 33040, 60600, 41249, 48948, 33982, 55668, 35940, 51016, 34378, 43570, 22344, 23097, 35616, 50920, 36572, 47824, 25862, 43036, 21584, 25226, 18832, 50520, 38698, 46967, 35960, 45963, 30264, 30040, 23376, 15960, 20978, 18472, 33808, 46786, 33448, 46656, 28688, 45036, 21994, 39304, 21540, 19424, 20078, 16524, 19504, 47109, 29436, 47112, 28136, 45891, 26184, 41555, 21766, 30528, 20464, 16396, 19868, 17522, 20516, 18350]
# GOOD M Divergent: divergent implant
# [29912, 24190, 34024, 30120, 33952, 50600, 28294, 30451, 23016, 46336, 34704, 28168, 32824, 17120, 25368, 22132, 39952, 43632, 33222, 35400, 30600, 19440, 26720, 21120, 20708, 41656, 39260, 40048, 38600, 15974, 31666, 17234, 26896, 17260, 22626, 22092, 39012, 42752, 36720, 40566, 32052, 34172, 26096, 21677, 26136, 20828, 25744, 22492, 22238, 40069, 40264, 41488, 39222, 36760, 31464, 31536, 27744, 15748, 24660, 20891, 23248, 21358, 22572, 23376]
# GOOD V-Shaped: V-shaped implant
# [23806, 34438, 30838, 33922, 33780, 60960, 31592, 36682, 21850, 47260, 38950, 33474, 36504, 21348, 25944, 21460, 42004, 46592, 37473, 40040, 30748, 33492, 22984, 20977, 22522, 44326, 41128, 41164, 39526, 34428, 30524, 18340, 24802, 21163, 23636, 22936, 41104, 41204, 37304, 41036, 32690, 40304, 25396, 33820, 22540, 22531, 21244, 24314, 22145, 40876, 35968, 43819, 33428, 39572, 29128, 33086, 25072, 25139, 23588, 21702, 21960, 21780, 22046, 20695]
# GOOD M ELRectangle: long rectangular implant
# [59072, 61682, 65766, 69862, 69164, 68490, 71140, 69932, 71696, 62734, 66040, 64332, 67686, 68160, 74216, 76141, 67664, 60512, 70856, 64889, 76339, 65337, 76568, 72096, 75832, 59336, 75762, 59344, 71302, 62092, 76552, 68327, 76052, 73537, 76400, 75144, 71212, 57551, 76339, 57552, 76356, 54650, 76208, 64786, 76336, 75124, 75768, 73074, 76257, 53452, 74280, 51179, 73852, 52568, 73376, 59140, 69058, 64420, 66970, 69072, 65504, 67020, 66588, 67046]
# GOOD-ELConvergent: long convergent implant
# [40522, 69909, 66689, 65422, 72365, 54517, 76303, 65850, 74906, 58796, 76225, 54033, 76610, 60406, 75845, 73651, 76606, 67855, 76813, 61738, 76707, 62906, 76264, 71597, 75651, 51643, 76787, 51588, 76652, 56669, 76871, 64042, 76485, 72268, 76339, 76308, 74876, 52768, 76717, 52313, 76782, 52503, 76670, 56846, 76440, 63470, 75082, 73942, 75210, 50280, 72165, 48948, 71028, 45275, 74885, 48986, 74371, 52000, 75923, 71630, 72347, 75108, 71324, 68664]
# GOOD-ELDivergent: long divergent implant
# [34460, 29234, 34945, 36367, 36475, 30109, 35897, 33934, 36239, 31962, 36531, 32238, 35432, 32606, 39002, 38648, 40095, 32922, 41780, 33229, 45573, 35814, 44000, 37969, 46927, 32912, 49549, 32838, 54970, 28408, 48532, 40297, 51047, 41516, 47676, 45544, 54986, 32270, 58512, 31962, 57972, 28860, 50906, 34348, 51171, 40197, 50650, 42002, 49148, 34520, 59516, 27683, 58808, 27426, 55777, 32934, 53433, 37092, 50477, 43535, 49282, 42352, 49259, 49096]
# GOOD ELV-shaped: long V-shaped implant
# [49801, 51020, 54348, 56912, 58044, 51187, 60244, 54004, 55219, 48916, 58516, 54453, 61246, 54845, 59750, 61653, 61840, 49146, 63424, 50770, 64792, 54219, 63970, 60726, 65477, 47736, 67850, 48832, 63583, 50864, 65626, 56562, 66884, 60092, 65682, 64170, 61947, 47740, 66242, 46283, 67548, 47577, 67414, 51644, 67896, 63764, 68030, 66338, 64383, 47220, 64976, 46354, 65164, 48122, 62675, 50048, 58689, 66276, 60114, 61766, 61882, 64735, 58929, 58022]

# %%
# %load "/extra/InVivoDog/Elazar/code_posture_onset/posture_onset.implant_rightSLNvsrightRLN_2013_10_23.py"

# After executing %load, a new cell containing the source code will be added.
# Be sure to add the next line (with the proper path) to overwrite the file
# with you changes.
#
# %%writefile ???

# %%
compare_lists_of_nerveconditions(onsettime_samples, nerve_conditions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8177f473946c> in <module>()
# ----> 1 compare_lists_of_nerveconditions(onsettime_samples, nerve_conditions)
#
# NameError: name 'nerve_conditions' is not defined

# %%
# compare_lists_of_nerveconditions(nerve_conditions, onsettime_samples)

# %%
# check that they are all the same length
for nervecond in nerve_conditions:
    print nervecond, len(onsettime_samples[nervecond])
# Out:
# GOOD M Baseline 64
# GOOD_No Implant 64
# GOOD-No Implant Repeat 64
# GOOD Rectangle 64
# GOOD M Convergent 64
# GOOD M Divergent 64
# GOOD V-Shaped 64
# GOOD M ELRectangle 64
# GOOD-ELConvergent 64
# GOOD-ELDivergent 64
# GOOD ELV-shaped 64

# %%
pwd
# Out:
# u'/extra/InVivoDog/Dinesh'

# %%
help write_inputdata_file
# Out:
# Help on function write_inputdata_file in module __main__:
#
# write_inputdata_file(filename=None, nerve_conditions=None, onsettime_samples=None)
#     write a csv file in /extra/InVivoDog/Elazar/inputdata

# %%
# !ls -alot /extra/InVivoDog/Elazar/inputdata
# Out:
# total 64
# -rw-r--r-- 1 neubauer 3499 Feb 19 11:21 implant_SLNvsRLN_2013_10_30_onsettime_samples.csv
# drwxr-xr-x 1 neubauer 1308 Feb 19 11:21 .
# -rw-r--r-- 1 neubauer 4263 Feb 18 22:45 implant_rightSLNvsrightRLN_2013_10_30_onsettime_samples.csv
# drwxr-xr-x 1 neubauer  264 Feb 18 10:46 ..
# -rw-r--r-- 1 neubauer 2982 Feb  5 14:38 implant_rightSLNvsrightRLN_2013_10_23_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 3364 Dec 15 13:29 implant_SLNvsRLN_2013_10_23_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 1914 Dec 15 11:33 RLNasymmetry_2013_12_11_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 2087 Nov 15 13:27 Adduction_rightSLN-rightRLN_4.4.12_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 2262 Nov 15 13:27 RLN Asymmetry_2.15.12_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 1893 Nov 15 13:27 RLN Asymmetry_4.4.12_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 3554 Nov 15 13:27 03_21_2012_SLNvsTrunk_F0.csv
# -rw-r--r-- 1 neubauer 1512 Nov 15 13:27 03_21_2012_SLNvsTrunk_onsettime.csv
# -rw-r--r-- 1 neubauer 3219 Nov 15 13:27 Adduction_2.22.12_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 2116 Nov 15 13:27 Adduction_symmetricSLN-rightRLN_4.4.12_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 2074 Nov 15 13:27 asymmetricTA_2012_05_09_onsettime_samples.csv
# -rw-r--r-- 1 neubauer 5359 Nov 15 13:27 asymmetricTA_2012_05_23_onsettime_samples.csv

# %%
write_inputdata_file(filename = 'implant_rightSLNvsrightRLN_2013_10_30_onsettime_samples.csv', 
                     nerve_conditions = nerve_conditions, 
                     onsettime_samples = onsettime_samples)

# %%
l = ["right SLN versus right RLN No implant_000_Wed Oct 23 2013 16 39 43.773 273.001.cine",
     "right SLN versus right RLN No implant_999_Wed Oct 23 2013 16 39 38.776 185.001.cine"]

# %%
sorted(l)
# Out:
# ['right SLN versus right RLN No implant_000_Wed Oct 23 2013 16 39 43.773 273.001.cine',
#  'right SLN versus right RLN No implant_999_Wed Oct 23 2013 16 39 38.776 185.001.cine']

# %%
import time, os

# %%
def datetimestamp(filename):

    fname = os.path.basename(filename)

    cleanf = os.path.splitext(fname)[0]

    # all our experiments are on Wednesdays!!!
    datestring, usec, nsec = cleanf.split('Wed')[-1].strip().split('.')

    return time.strptime(datestring, '%b %d %Y %H %M %S')

# %%
sorted(l, key = datetimestamp)
# Out:
# ['right SLN versus right RLN No implant_999_Wed Oct 23 2013 16 39 38.776 185.001.cine',
#  'right SLN versus right RLN No implant_000_Wed Oct 23 2013 16 39 43.773 273.001.cine']
