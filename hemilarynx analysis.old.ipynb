# %% [markdown]
# OLD CODE
# =========

# %%
hemi_dir = '/mnt/workspace/InVivoDog_2012_10_10/left TA/range_finding'

hemi_filename = 'left TA range_finding_071_Wed Oct 10 2012 15 02 57.492 437.001.cine'

hemi_dir = '/mnt/workspace/InVivoDog_2012_10_10/TA-trunkRLN/NoSLN/'
hemi_filenames = sorted(glob.glob(os.path.join(hemi_dir, '*.cine')))
print "number of cine files in this directory: ", len(hemi_filenames)

stimindex = 5 * 5 + 1

hemi_filename = os.path.basename(hemi_filenames[stimindex - 1])

if False:
    hemi_dir = '/mnt/workspace/InVivoDog_2012_10_10/calibration/'
    hemi_filename = 'calibration_001_Wed Oct 10 2012 14 40 21.189 567.001_Cam_11440_Cine2.cine'

    hemi_filename = None
# Out:
# number of cine files in this directory:  81

# %%
hemi_dir = '/mnt/workspace/InVivoDog_2012_10_17/'
hemi_filename = None

# %%
exp_cine_dirs = glob.glob(os.path.join(hemi_dir, 'left*'))

exp_cine_dirs = [hemi_dir]
print "experimental cine dirs: ", exp_cine_dirs

for expdir in exp_cine_dirs:
    for dirpath, dirnames, filenames in os.walk(expdir):
        print "dirpath: ", dirpath
        for filename in filenames:
            if not filename.endswith('.cine'):
                continue
            c = Cine(initialdir = dirpath, cinefilename = filename, debug = True)
            
            fall = c.getallframes()

            raw_frames_dir = c.cinefilename.replace('.cine', '.frames_raw')
            os.makedirs(raw_frames_dir)
            
            for num, frame in enumerate(fall):
                raw_cine_name = c.cinefilename.replace('.cine', '.frame%04d.raww' % num)
                raw_cine_filepath = os.path.join(raw_frames_dir, os.path.basename(raw_cine_name))
                frame.tofile(raw_cine_filepath)

print "exported all frames from cine to binary file (raww: uint16)"
print "pixel geometry: ", frame.shape
# Out:
# experimental cine dirs:  ['/mnt/workspace/InVivoDog_2012_10_17/']
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/left PCA
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/left PCA/range finding
# getallrawframes:
# disk reading time: 28234.269 milliseconds
# disk reading rate: 49.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 44579.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 7481.970 milliseconds
# disk reading rate: 185.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 33833.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1574.474 milliseconds
# disk reading rate: 879.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 35047.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1677.410 milliseconds
# disk reading rate: 825.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 39373.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1423.377 milliseconds
# disk reading rate: 972.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22161.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1434.617 milliseconds
# disk reading rate: 964.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29146.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1310.921 milliseconds
# disk reading rate: 1056.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13147.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1627.232 milliseconds
# disk reading rate: 850.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25611.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1482.814 milliseconds
# disk reading rate: 933.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11519.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1524.320 milliseconds
# disk reading rate: 908.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29602.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1884.096 milliseconds
# disk reading rate: 734.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11395.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 3496.021 milliseconds
# disk reading rate: 396.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25894.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1261.101 milliseconds
# disk reading rate: 1097.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13958.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1585.474 milliseconds
# disk reading rate: 873.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23057.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1337.275 milliseconds
# disk reading rate: 1035.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16140.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 9931.198 milliseconds
# disk reading rate: 139.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 33781.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1251.986 milliseconds
# disk reading rate: 1105.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20940.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1197.835 milliseconds
# disk reading rate: 1155.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21052.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1429.033 milliseconds
# disk reading rate: 968.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19888.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1793.391 milliseconds
# disk reading rate: 771.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14089.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1452.396 milliseconds
# disk reading rate: 953.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21909.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1268.657 milliseconds
# disk reading rate: 1091.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29687.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1230.393 milliseconds
# disk reading rate: 1125.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25987.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1986.399 milliseconds
# disk reading rate: 696.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20842.7 milli sec
# -------------------------------------------------------
#
# dirpath:
#  /mnt/workspace/InVivoDog_2012_10_17/trunkRLN-PCA
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/trunkRLN-PCA/only
# getallrawframes:
# disk reading time: 1498.436 milliseconds
# disk reading rate: 923.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27124.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1742.017 milliseconds
# disk reading rate: 794.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14261.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2272.282 milliseconds
# disk reading rate: 609.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20719.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1738.834 milliseconds
# disk reading rate: 796.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13087.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1991.197 milliseconds
# disk reading rate: 695.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 28016.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1624.589 milliseconds
# disk reading rate: 852.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12987.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1868.786 milliseconds
# disk reading rate: 740.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25798.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1639.378 milliseconds
# disk reading rate: 844.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12507.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1600.295 milliseconds
# disk reading rate: 865.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23361.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1716.661 milliseconds
# disk reading rate: 806.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 10800.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2115.998 milliseconds
# disk reading rate: 654.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 36271.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1816.002 milliseconds
# disk reading rate: 762.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12308.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1834.158 milliseconds
# disk reading rate: 754.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24909.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1772.332 milliseconds
# disk reading rate: 781.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15051.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1622.211 milliseconds
# disk reading rate: 853.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24354.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2362.481 milliseconds
# disk reading rate: 586.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16802.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 3125.561 milliseconds
# disk reading rate: 442.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 32070.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1869.042 milliseconds
# disk reading rate: 740.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12482.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1826.394 milliseconds
# disk reading rate: 757.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22153.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1555.777 milliseconds
# disk reading rate: 889.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18457.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1763.770 milliseconds
# disk reading rate: 784.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 31556.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1781.197 milliseconds
# disk reading rate: 777.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 31349.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1533.835 milliseconds
# disk reading rate: 902.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16873.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1770.979 milliseconds
# disk reading rate: 781.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18402.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2155.534 milliseconds
# disk reading rate: 642.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16050.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1693.658 milliseconds
# disk reading rate: 817.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17454.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1690.520 milliseconds
# disk reading rate: 818.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14467.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1451.353 milliseconds
# disk reading rate: 953.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20346.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1828.310 milliseconds
# disk reading rate: 757.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12649.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1523.076 milliseconds
# disk reading rate: 908.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27093.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1923.995 milliseconds
# disk reading rate: 719.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17778.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1560.931 milliseconds
# disk reading rate: 886.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18419.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2665.266 milliseconds
# disk reading rate: 519.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12651.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 3235.583 milliseconds
# disk reading rate: 427.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21260.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1652.478 milliseconds
# disk reading rate: 837.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13955.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1562.087 milliseconds
# disk reading rate: 886.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19666.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1931.222 milliseconds
# disk reading rate: 716.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11277.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1517.863 milliseconds
# disk reading rate: 912.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 32632.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2230.732 milliseconds
# disk reading rate: 620.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11181.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1962.351 milliseconds
# disk reading rate: 705.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21856.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1582.918 milliseconds
# disk reading rate: 874.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 10409.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2023.524 milliseconds
# disk reading rate: 684.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25985.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1996.103 milliseconds
# disk reading rate: 693.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15510.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2317.970 milliseconds
# disk reading rate: 597.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23626.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2019.403 milliseconds
# disk reading rate: 685.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14857.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1852.639 milliseconds
# disk reading rate: 747.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25443.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1649.673 milliseconds
# disk reading rate: 839.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14615.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1530.528 milliseconds
# disk reading rate: 904.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19290.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1706.602 milliseconds
# disk reading rate: 811.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 28198.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2043.350 milliseconds
# disk reading rate: 677.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25180.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2002.880 milliseconds
# disk reading rate: 691.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22303.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1849.555 milliseconds
# disk reading rate: 748.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14414.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1584.718 milliseconds
# disk reading rate: 873.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29674.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1430.040 milliseconds
# disk reading rate: 968.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19240.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1475.230 milliseconds
# disk reading rate: 938.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25758.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1679.781 milliseconds
# disk reading rate: 824.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16430.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1840.260 milliseconds
# disk reading rate: 752.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18977.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2153.853 milliseconds
# disk reading rate: 642.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20010.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2001.295 milliseconds
# disk reading rate: 691.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21851.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2014.902 milliseconds
# disk reading rate: 687.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15935.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1982.073 milliseconds
# disk reading rate: 698.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23320.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1364.344 milliseconds
# disk reading rate: 1014.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27606.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1921.470 milliseconds
# disk reading rate: 720.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19373.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1567.196 milliseconds
# disk reading rate: 883.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19521.0 milli sec
# -------------------------------------------------------
#
# dirpath:
#  /mnt/workspace/InVivoDog_2012_10_17/PCA-TA
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/PCA-TA/only_improved TA range
# getallrawframes:
# disk reading time: 1387.643 milliseconds
# disk reading rate: 997.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27856.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2769.270 milliseconds
# disk reading rate: 499.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 34606.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1669.046 milliseconds
# disk reading rate: 829.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 26449.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1694.055 milliseconds
# disk reading rate: 817.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21807.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1695.388 milliseconds
# disk reading rate: 816.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14975.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1856.932 milliseconds
# disk reading rate: 745.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20503.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1503.136 milliseconds
# disk reading rate: 920.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17184.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 3391.338 milliseconds
# disk reading rate: 408.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23053.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1278.359 milliseconds
# disk reading rate: 1082.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15189.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1495.984 milliseconds
# disk reading rate: 925.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20885.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1414.039 milliseconds
# disk reading rate: 979.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 28494.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1656.753 milliseconds
# disk reading rate: 835.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22043.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1239.307 milliseconds
# disk reading rate: 1117.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22503.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1456.049 milliseconds
# disk reading rate: 950.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22853.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1332.537 milliseconds
# disk reading rate: 1038.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23056.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1505.908 milliseconds
# disk reading rate: 919.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14873.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1504.246 milliseconds
# disk reading rate: 920.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22972.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1972.219 milliseconds
# disk reading rate: 701.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14674.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1691.861 milliseconds
# disk reading rate: 818.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25409.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1439.019 milliseconds
# disk reading rate: 962.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 32393.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1547.546 milliseconds
# disk reading rate: 894.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14778.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1279.913 milliseconds
# disk reading rate: 1081.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24648.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1851.583 milliseconds
# disk reading rate: 747.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14309.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1581.537 milliseconds
# disk reading rate: 875.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22566.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1477.172 milliseconds
# disk reading rate: 937.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18404.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1751.349 milliseconds
# disk reading rate: 790.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 31232.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1467.724 milliseconds
# disk reading rate: 943.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21131.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1695.255 milliseconds
# disk reading rate: 816.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22574.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1366.987 milliseconds
# disk reading rate: 1012.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 30224.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1474.716 milliseconds
# disk reading rate: 938.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27574.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1355.919 milliseconds
# disk reading rate: 1020.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29213.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1626.435 milliseconds
# disk reading rate: 851.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16320.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1245.046 milliseconds
# disk reading rate: 1111.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 30502.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1304.349 milliseconds
# disk reading rate: 1061.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21669.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1539.284 milliseconds
# disk reading rate: 899.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18640.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1665.276 milliseconds
# disk reading rate: 831.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 30498.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1312.527 milliseconds
# disk reading rate: 1054.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22148.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1371.989 milliseconds
# disk reading rate: 1009.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14899.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1401.522 milliseconds
# disk reading rate: 987.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12726.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 3075.643 milliseconds
# disk reading rate: 450.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24387.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1481.039 milliseconds
# disk reading rate: 934.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22275.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1428.293 milliseconds
# disk reading rate: 969.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24822.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1660.843 milliseconds
# disk reading rate: 833.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15165.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1662.659 milliseconds
# disk reading rate: 832.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21223.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1648.613 milliseconds
# disk reading rate: 839.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 30234.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1771.572 milliseconds
# disk reading rate: 781.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19907.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1658.975 milliseconds
# disk reading rate: 834.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 26217.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1252.500 milliseconds
# disk reading rate: 1105.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14328.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1904.686 milliseconds
# disk reading rate: 726.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17981.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1210.918 milliseconds
# disk reading rate: 1143.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 10786.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1467.375 milliseconds
# disk reading rate: 943.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19528.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1374.454 milliseconds
# disk reading rate: 1007.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 10564.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1857.404 milliseconds
# disk reading rate: 745.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 26955.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1292.737 milliseconds
# disk reading rate: 1070.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17222.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2783.854 milliseconds
# disk reading rate: 497.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 33374.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1644.584 milliseconds
# disk reading rate: 841.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14541.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 4002.703 milliseconds
# disk reading rate: 345.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 29802.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1332.489 milliseconds
# disk reading rate: 1038.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13796.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1438.262 milliseconds
# disk reading rate: 962.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19869.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1316.411 milliseconds
# disk reading rate: 1051.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11281.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1397.638 milliseconds
# disk reading rate: 990.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 26143.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1511.358 milliseconds
# disk reading rate: 915.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# ...
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21876.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1945.958 milliseconds
# disk reading rate: 711.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 24481.4 milli sec
# -------------------------------------------------------
#
# dirpath:
#  /mnt/workspace/InVivoDog_2012_10_17/left RLN
# dirpath:  /mnt/workspace/InVivoDog_2012_10_17/left RLN/range finding
# getallrawframes:
# disk reading time: 1771.216 milliseconds
# disk reading rate: 781.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25004.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1577.811 milliseconds
# disk reading rate: 877.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15445.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1553.507 milliseconds
# disk reading rate: 891.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21620.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1588.430 milliseconds
# disk reading rate: 871.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17994.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 4341.066 milliseconds
# disk reading rate: 318.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15201.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2094.837 milliseconds
# disk reading rate: 660.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15986.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1877.947 milliseconds
# disk reading rate: 737.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20905.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1315.731 milliseconds
# disk reading rate: 1052.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17001.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1390.529 milliseconds
# disk reading rate: 995.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 34319.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1757.909 milliseconds
# disk reading rate: 787.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14269.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 5231.657 milliseconds
# disk reading rate: 264.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 33506.7 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1998.810 milliseconds
# disk reading rate: 692.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 12915.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1603.614 milliseconds
# disk reading rate: 863.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 25715.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2190.317 milliseconds
# disk reading rate: 632.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 11662.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1930.237 milliseconds
# disk reading rate: 717.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 27373.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1897.739 milliseconds
# disk reading rate: 729.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14798.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2458.758 milliseconds
# disk reading rate: 563.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 34366.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1423.600 milliseconds
# disk reading rate: 972.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20653.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1800.276 milliseconds
# disk reading rate: 768.9 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23583.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1550.038 milliseconds
# disk reading rate: 893.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14402.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1407.876 milliseconds
# disk reading rate: 983.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23064.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1749.508 milliseconds
# disk reading rate: 791.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17956.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1777.524 milliseconds
# disk reading rate: 778.8 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16724.3 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1877.166 milliseconds
# disk reading rate: 737.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21127.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1536.329 milliseconds
# disk reading rate: 901.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 28272.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1744.602 milliseconds
# disk reading rate: 793.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16027.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 4241.895 milliseconds
# disk reading rate: 326.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 30714.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1841.483 milliseconds
# disk reading rate: 751.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 13555.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1356.199 milliseconds
# disk reading rate: 1020.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20910.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1432.332 milliseconds
# disk reading rate: 966.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14581.5 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1468.721 milliseconds
# disk reading rate: 942.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 32604.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1263.721 milliseconds
# disk reading rate: 1095.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 22378.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2002.369 milliseconds
# disk reading rate: 691.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19316.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1399.484 milliseconds
# disk reading rate: 989.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21945.2 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1578.951 milliseconds
# disk reading rate: 876.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14402.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 2630.560 milliseconds
# disk reading rate: 526.2 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 16559.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1675.375 milliseconds
# disk reading rate: 826.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 23833.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1990.452 milliseconds
# disk reading rate: 695.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 20968.1 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1935.080 milliseconds
# disk reading rate: 715.4 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 18667.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1339.700 milliseconds
# disk reading rate: 1033.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14652.0 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1400.174 milliseconds
# disk reading rate: 988.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 17409.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1464.455 milliseconds
# disk reading rate: 945.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15872.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1706.901 milliseconds
# disk reading rate: 811.0 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14636.6 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1459.446 milliseconds
# disk reading rate: 948.5 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 15391.8 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1494.043 milliseconds
# disk reading rate: 926.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 21053.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1951.660 milliseconds
# disk reading rate: 709.3 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19284.9 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1471.656 milliseconds
# disk reading rate: 940.6 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 19693.4 milli sec
# -------------------------------------------------------
#
# getallrawframes:
# disk reading time: 1809.303 milliseconds
# disk reading rate: 765.1 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4500 frames
# 	conversion time: 14583.1 milli sec
# -------------------------------------------------------
#
# exported all frames from cine to binary file (raww: uint16)
# pixel geometry:  (672, 384)

# %%
# %connect_info
# Out:
# {
#   "stdin_port": 48650,
#   "ip": "127.0.0.1",
#   "hb_port": 52119,
#   "key": "57e43739-3c4d-49f8-8411-56315bc7828a",
#   "shell_port": 56386,
#   "iopub_port": 39296
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing kernel-5a5e062e-647b-4a80-9316-47094f0cb063.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.

# %%
c = Cine(initialdir = hemi_dir, cinefilename = hemi_filename, debug = True)
print "read cine file: ", c.cinefilename
# Out:
# ==================================================
# selected cine file:
# 	/mnt/workspace/InVivoDog_2012_09_26/calibration_phonatory_posturing_smaller_gap/calibration_001_Wed Sep 26 2012 17 04 27.158 409.001_Cam_11440_Cine2.cine
#
# ==================================================
# read cine file:
#  /mnt/workspace/InVivoDog_2012_09_26/calibration_phonatory_posturing_smaller_gap/calibration_001_Wed Sep 26 2012 17 04 27.158 409.001_Cam_11440_Cine2.cine

# %%
print "Npixel: ", c.Npixel
print "frame rate: ", c.framerate
print "imagecount: ", c.imagecount
print "imagesize: ", c.imagesize
print "bitmapheader: ", c.bitmapheader
print "frame height: ", c.height
print "frame width: ", c.width
# Out:
# Npixel:  262144
# frame rate:  3000
# imagecount:  4501
# imagesize:  327680
# bitmapheader:  {'bisizeimage': 327680L, 'bicompression': 256L, 'biypelspermeter': 50000, 'biplanes': 1, 'bibitcount': 16, 'bisize': 40L, 'biclrused': 0L, 'biclrimportant': 1024L, 'biheight': 512, 'bixpelspermeter': 50000, 'biwidth': 512}
# frame height:  512
# frame width:  512

# %%
import time
f0 = dict()
c.debug = False

t0 = time.time()
for num, framenum in enumerate(range(0, 300, 3)):
    f0[num] = c.getframe(framenum)[0]

dt = time.time() - t0
f0nbytes = sum(np.array([item.nbytes for item in f0.values()]))

print "disk reading time: %.3f milliseconds" % (dt * 1000.0)
print "disk reading rate: %.1f MB/s" % (f0nbytes / dt / 2.**20)

print "shape: ", f0[0].shape
# Out:
# disk reading time: 315.401 milliseconds
# disk reading rate: 158.5 MB/s
# shape:  (512, 512)

# %%
imshow(f0[0], aspect = 'equal', origin = 'upper')
grid(False)

# %%
imshow(np.fliplr(f0[0].T), aspect = 'equal', origin = 'upper')
grid(False)

# %%
imshow(np.fliplr(f0[0][ 200:, :].T), aspect = 'equal', origin = 'upper')
grid(False)

# %%
c.debug = True
fall = c.getallframes()
# Out:
# getallrawframes:
# disk reading time: 2625.533 milliseconds
# disk reading rate: 535.7 MB/s
# -------------------------------------------------------
# converting raw packed pixel data to uint16 pixel arrays:
# 	converted 4501 frames
# 	conversion time: 28245.4 milli sec
# -------------------------------------------------------

# %%
raw_frames_dir = c.cinefilename.replace('.cine', '.frames_raw')
os.makedirs(raw_frames_dir)

# %%
for num, frame in enumerate(fall):
    raw_cine_name = c.cinefilename.replace('.cine', '.frame%04d.raww' % num)
    raw_cine_filepath = os.path.join(raw_frames_dir, os.path.basename(raw_cine_name))
    frame.tofile(raw_cine_filepath)

print "exported all frames from cine to binary file (raww: uint16)"
print "pixel geometry: ", frame.shape
# Out:
# exported all frames from cine to binary file (raww: uint16)
# pixel geometry:  (512, 512)

# %%
imshow(frame, origin = 'upper', aspect = 'equal')

# %%
thumb_every_N_millisec = 5
thumbstrip = fall[::thumb_every_N_millisec * 3, 400::6, ::6]
print "", fall.shape
print "", thumbstrip.shape
Nt, ht, wt = thumbstrip.shape
# Out:
#  (4501, 512, 512)
#  (301, 19, 86)

# %%
Nthumbs = 15
print "thumbstrip shows %d millisec" % (Nthumbs * thumb_every_N_millisec)
thumbs = np.empty((wt, Nthumbs * ht), dtype = thumbstrip.dtype)
for num, frame in enumerate(thumbstrip[:Nthumbs]):
    thumbs[:, num*ht:(num+1)*ht] = np.fliplr(frame.T)
# Out:
# thumbstrip shows 75 millisec

# %%
imshow(thumbs, 
       aspect = 'equal', 
       origin = 'upper')
grid(False)

# %%
kymo = fall[:, 525, :]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-6281eb701008> in <module>()
# ----> 1 kymo = fall[:, 525, :]
#
# IndexError: index 525 is out of bounds for axis 1 with size 512

# %%
imshow(kymo[:300].T, origin = 'upper')
xlabel('time [frames]')

# %%
import Image

# %%
Image.fromarray(f0[0].astype(np.uint8))
# Out:
# <Image.Image image mode=L size=384x672 at 0x5FA2E18>

# %%
imshow(f0[0].astype(np.uint8))

# %%
kymo = c.makekymo(None, linenr = 525)
# Out:
# ****************************************
# makekymo_from_raw: reading data for kymogram
#
# total seektime [ms]: 2629.584
# total readtime [ms]: 437.950
#
# max seektime [ms]: 21.845
# max readtime [ms]: 7.872
#
# temp_pixdat: read 2.060 MB
# total data reading time: 3098.376 millisec
# total data reading rate: 0.665 MB/s
#
# ****************************************

# %%
imshow(kymo, origin = 'lower', aspect = 'auto')
