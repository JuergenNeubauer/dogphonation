# %%
import sys, glob, os
import numpy as np

import matplotlib as mpl
# mpl.use('module://IPython.zmq.pylab.backend_inline')
import matplotlib.pyplot as plt

mpl.rcParams['figure.figsize'] = (6, 4)
mpl.rcParams['image.cmap'] = 'jet'

sys.path.append("/extra/InVivoDog/python/cine/tools")

from dogdata import DogData

import xlrd

# %%
colorlist = ['c', 'b', 'g', 'm', 'r']
cmap = mpl.colors.ListedColormap(colorlist)

symblist = ['*', '+', '^', 'v', 'o']

# %%
for SLNnum, (SLNcond, SLNcondname) in enumerate(zip(SLNconditions, SLNconditions_names)):

    dogdata = DogData(datadir = datadir, datafile = datafiles[SLNcond])
    print "working on: ", dogdata.datafilename
    
    Nrecnums = dogdata.Nrecnums
    
    sheet_SLNcond = book.sheet_by_name(SLNcondname)
    print "getting data from Excel sheet: ", sheet_SLNcond.name
    print
    
    # prepare lists to hold these numbers for the different SLN conditions
    onset_time[ SLNcond ] = []
    F0[ SLNcond ] = []
    
    for recnum in range(Nrecnums):
        # Onset sample, Onset time, #Peaks, Time (samples)
        onset, dummy, Npeaks, T = sheet_SLNcond.row_values(4 + recnum, start_colx = 1, end_colx = 5) # exclusive end_colx
        if onset in ['NP', '', ' ']:
            onset = np.nan
        else:
            onset = int(onset)
            
        # onset time in samples: sampling rate of audio signal: 50 KHz
        onset_time[ SLNcond ].append( onset / 50.0 ) # onset time in milliseconds
        
        if T in ['', ' ']:
            T = np.nan
        else:
            T = int(T)
            
        F0[ SLNcond ].append( Npeaks * 50.0 / float(T) * 1000.0 )
# Out:
# working on:  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN NoSLN Wed Apr 04 2012 14 51 58.hdf5
# getting data from Excel sheet:  No SLN
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN ThresholdSLN_condition01 Wed Apr 04 2012 14 59 14.hdf5
# getting data from Excel sheet:  Threshold SLN
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN SLN_condition02 Wed Apr 04 2012 15 09 45.hdf5
# getting data from Excel sheet:  SLN 2
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN SLN_condition03 Wed Apr 04 2012 15 17 06.hdf5
# getting data from Excel sheet:  SLN 3
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN MaxSLN_condition04 Wed Apr 04 2012 15 25 32.hdf5
# getting data from Excel sheet:  Max SLN

# %%
a_F0 = np.array([F0[item] for item in sorted(F0)]).T
a_onset = np.array([onset_time[item] for item in sorted(onset_time)]).T

# %%
a_onset.shape
# Out:
# (64, 5)

# %%
assert a_onset.shape == (64, 5)

# %%
ps_onset = np.ones(a_onset.shape) * np.nan
Q_onset = np.ones(a_onset.shape) * np.nan

ps_noonset = np.ones(a_onset.shape) * np.nan
Q_noonset = np.ones(a_onset.shape) * np.nan

# Bernoulli equivalent area A proportional to Q / sqrt(p)
A_onset = np.ones(a_onset.shape) * np.nan
A_noonset = np.ones(a_onset.shape) * np.nan

# %%
zip(SLNconditions, SLNconditions_names)
# Out:
# [('SLN 0', 'No SLN'),
#  ('SLN 1', 'Threshold SLN'),
#  ('SLN 2', 'SLN 2'),
#  ('SLN 3', 'SLN 3'),
#  ('SLN 4', 'Max SLN')]

# %%
for SLNnum, (SLNcond, SLNcondname) in enumerate(zip(SLNconditions, SLNconditions_names)):

    dogdata = DogData(datadir = datadir, datafile = datafiles[SLNcond])
    print "working on: ", dogdata.datafilename
    dogdata.get_all_data()

    time = dogdata.time_psQ * 1000.0 # onset time is given in milliseconds
    
    for stimind, datarow in enumerate(dogdata.allps):
        if not np.isnan(a_onset[stimind, SLNnum]):
            # linear interpolation
            ps_onset[stimind, SLNnum] = np.interp(a_onset[stimind, SLNnum], time, datarow)
        else:
            ps_noonset[stimind, SLNnum] = datarow.max()

    for stimind, datarow in enumerate(dogdata.allQ):
        if not np.isnan(a_onset[stimind, SLNnum]):
            Q_onset[stimind, SLNnum] = np.interp(a_onset[stimind, SLNnum], time, datarow)
        else:
            # the maximum flow rate should always be constant as set by the flow controller for the max of the flow ramp
            Q_noonset[stimind, SLNnum] = datarow.max()

A_onset = Q_onset / np.sqrt(ps_onset)
A_noonset = Q_noonset / np.sqrt(ps_noonset)
# Out:
# working on:  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN NoSLN Wed Apr 04 2012 14 51 58.hdf5
# reading entire data from hdf5 file
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN ThresholdSLN_condition01 Wed Apr 04 2012 14 59 14.hdf5
# reading entire data from hdf5 file
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN SLN_condition02 Wed Apr 04 2012 15 09 45.hdf5
# reading entire data from hdf5 file
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN SLN_condition03 Wed Apr 04 2012 15 17 06.hdf5
# reading entire data from hdf5 file
#
# working on:
#  /extra/InVivoDog/Dinesh/RLN_asymmetry/InVivoDog_2012_04_04/asymmetricRLN MaxSLN_condition04 Wed Apr 04 2012 15 25 32.hdf5
# reading entire data from hdf5 file

# %%
# onset, dummy, dummy, T = sheet_SLNcond.row_values((4 - 1) + 6, start_colx = 1, end_colx = 5)

# %% [markdown]
# Get landmark clicks
# ===================

# %%
# landmarks at rest and onset clicked by Eli
# if onset didn't occur, used the last frame in recording
# see strainanalysis.py
landmarkdir = "/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/"

print "%s exists? " % landmarkdir, os.path.isdir(landmarkdir)

clickfiles = sorted(glob.glob(os.path.join(landmarkdir, '*.npz')))
# Out:
# /extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/ exists?  True

# %%
clickfiles
# Out:
# ['/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_256_triggered_Wed Apr 04 2012 15 26 06.366 602.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_257_triggered_Wed Apr 04 2012 15 26 11.357 728.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_258_triggered_Wed Apr 04 2012 15 26 16.348 855.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_259_triggered_Wed Apr 04 2012 15 26 21.339 981.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_260_triggered_Wed Apr 04 2012 15 26 26.331 108.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_261_triggered_Wed Apr 04 2012 15 26 31.322 235.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_262_triggered_Wed Apr 04 2012 15 26 36.313 361.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_263_triggered_Wed Apr 04 2012 15 26 41.304 488.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_264_triggered_Wed Apr 04 2012 15 26 46.295 614.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_265_triggered_Wed Apr 04 2012 15 26 51.286 741.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_266_triggered_Wed Apr 04 2012 15 26 56.277 868.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_267_triggered_Wed Apr 04 2012 15 27 01.268 994.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_268_triggered_Wed Apr 04 2012 15 27 06.260 121.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_269_triggered_Wed Apr 04 2012 15 27 11.251 247.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_270_triggered_Wed Apr 04 2012 15 27 16.242 374.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_271_triggered_Wed Apr 04 2012 15 27 21.233 501.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_272_triggered_Wed Apr 04 2012 15 27 26.224 627.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_273_triggered_Wed Apr 04 2012 15 27 31.215 754.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_274_triggered_Wed Apr 04 2012 15 27 36.206 880.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_275_triggered_Wed Apr 04 2012 15 27 41.198 007.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_276_triggered_Wed Apr 04 2012 15 27 46.189 134.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_277_triggered_Wed Apr 04 2012 15 27 51.180 260.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_278_triggered_Wed Apr 04 2012 15 27 56.171 387.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_279_triggered_Wed Apr 04 2012 15 28 01.162 513.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_280_triggered_Wed Apr 04 2012 15 28 06.153 640.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_281_triggered_Wed Apr 04 2012 15 28 11.144 767.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_282_triggered_Wed Apr 04 2012 15 28 16.135 893.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_283_triggered_Wed Apr 04 2012 15 28 21.127 020.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_284_triggered_Wed Apr 04 2012 15 28 26.118 146.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_285_triggered_Wed Apr 04 2012 15 28 31.109 273.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_286_triggered_Wed Apr 04 2012 15 28 36.100 400.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_287_triggered_Wed Apr 04 2012 15 28 41.091 526.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_288_triggered_Wed Apr 04 2012 15 28 46.082 653.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_289_triggered_Wed Apr 04 2012 15 28 51.073 780.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_290_triggered_Wed Apr 04 2012 15 28 56.064 906.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_291_triggered_Wed Apr 04 2012 15 29 01.056 033.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_292_triggered_Wed Apr 04 2012 15 29 06.047 159.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_293_triggered_Wed Apr 04 2012 15 29 11.038 286.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_294_triggered_Wed Apr 04 2012 15 29 16.029 413.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_295_triggered_Wed Apr 04 2012 15 29 21.020 539.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_296_triggered_Wed Apr 04 2012 15 29 26.011 666.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_297_triggered_Wed Apr 04 2012 15 29 31.002 792.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_298_triggered_Wed Apr 04 2012 15 29 35.993 919.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_299_triggered_Wed Apr 04 2012 15 29 40.985 046.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_300_triggered_Wed Apr 04 2012 15 29 45.976 172.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_301_triggered_Wed Apr 04 2012 15 29 50.967 299.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_302_triggered_Wed Apr 04 2012 15 29 55.958 426.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_303_triggered_Wed Apr 04 2012 15 30 00.949 552.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_304_triggered_Wed Apr 04 2012 15 30 05.940 679.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_305_triggered_Wed Apr 04 2012 15 30 10.931 805.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_306_triggered_Wed Apr 04 2012 15 30 15.922 932.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_307_triggered_Wed Apr 04 2012 15 30 20.914 059.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_308_triggered_Wed Apr 04 2012 15 30 25.905 185.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_309_triggered_Wed Apr 04 2012 15 30 30.896 312.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_310_triggered_Wed Apr 04 2012 15 30 35.887 439.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_311_triggered_Wed Apr 04 2012 15 30 40.878 565.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_312_triggered_Wed Apr 04 2012 15 30 45.869 692.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_313_triggered_Wed Apr 04 2012 15 30 50.860 818.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_314_triggered_Wed Apr 04 2012 15 30 55.851 945.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_315_triggered_Wed Apr 04 2012 15 31 00.843 072.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_316_triggered_Wed Apr 04 2012 15 31 05.834 198.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_317_triggered_Wed Apr 04 2012 15 31 10.825 325.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_318_triggered_Wed Apr 04 2012 15 31 15.816 452.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_MaxSLN_condition04_319_triggered_Wed Apr 04 2012 15 31 20.807 578.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_000_triggered_Wed Apr 04 2012 14 52 32.836 526.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_001_triggered_Wed Apr 04 2012 14 52 37.827 652.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_002_triggered_Wed Apr 04 2012 14 52 42.818 778.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_003_triggered_Wed Apr 04 2012 14 52 47.809 904.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_004_triggered_Wed Apr 04 2012 14 52 52.801 031.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_005_triggered_Wed Apr 04 2012 14 52 57.792 157.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_006_triggered_Wed Apr 04 2012 14 53 02.783 283.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_007_triggered_Wed Apr 04 2012 14 53 07.774 409.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_008_triggered_Wed Apr 04 2012 14 53 12.765 536.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_009_triggered_Wed Apr 04 2012 14 53 17.756 662.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_010_triggered_Wed Apr 04 2012 14 53 22.747 788.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_011_triggered_Wed Apr 04 2012 14 53 27.738 914.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_012_triggered_Wed Apr 04 2012 14 53 32.730 040.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_013_triggered_Wed Apr 04 2012 14 53 37.721 167.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_014_triggered_Wed Apr 04 2012 14 53 42.712 293.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_015_triggered_Wed Apr 04 2012 14 53 47.703 419.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_016_triggered_Wed Apr 04 2012 14 53 52.694 545.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_017_triggered_Wed Apr 04 2012 14 53 57.685 672.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_018_triggered_Wed Apr 04 2012 14 54 02.676 798.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_019_triggered_Wed Apr 04 2012 14 54 07.667 924.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_020_triggered_Wed Apr 04 2012 14 54 12.659 051.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_021_triggered_Wed Apr 04 2012 14 54 17.650 177.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_022_triggered_Wed Apr 04 2012 14 54 22.641 303.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_023_triggered_Wed Apr 04 2012 14 54 27.632 429.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_024_triggered_Wed Apr 04 2012 14 54 32.623 556.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_025_triggered_Wed Apr 04 2012 14 54 37.614 682.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_026_triggered_Wed Apr 04 2012 14 54 42.605 808.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_027_triggered_Wed Apr 04 2012 14 54 47.596 934.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_028_triggered_Wed Apr 04 2012 14 54 52.588 061.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_029_triggered_Wed Apr 04 2012 14 54 57.579 187.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_030_triggered_Wed Apr 04 2012 14 55 02.570 313.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_031_triggered_Wed Apr 04 2012 14 55 07.561 440.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_032_triggered_Wed Apr 04 2012 14 55 12.552 566.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_033_triggered_Wed Apr 04 2012 14 55 17.543 692.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_034_triggered_Wed Apr 04 2012 14 55 22.534 818.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_035_triggered_Wed Apr 04 2012 14 55 27.525 945.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_036_triggered_Wed Apr 04 2012 14 55 32.517 071.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_037_triggered_Wed Apr 04 2012 14 55 37.508 197.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_038_triggered_Wed Apr 04 2012 14 55 42.499 324.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_039_triggered_Wed Apr 04 2012 14 55 47.490 450.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_040_triggered_Wed Apr 04 2012 14 55 52.481 576.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_041_triggered_Wed Apr 04 2012 14 55 57.472 703.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_042_triggered_Wed Apr 04 2012 14 56 02.463 829.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_043_triggered_Wed Apr 04 2012 14 56 07.454 955.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_044_triggered_Wed Apr 04 2012 14 56 12.446 082.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_045_triggered_Wed Apr 04 2012 14 56 17.437 208.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_046_triggered_Wed Apr 04 2012 14 56 22.428 334.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_047_triggered_Wed Apr 04 2012 14 56 27.419 460.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_048_triggered_Wed Apr 04 2012 14 56 32.410 587.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_049_triggered_Wed Apr 04 2012 14 56 37.401 713.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_050_triggered_Wed Apr 04 2012 14 56 42.392 839.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_051_triggered_Wed Apr 04 2012 14 56 47.383 966.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_052_triggered_Wed Apr 04 2012 14 56 52.375 092.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_053_triggered_Wed Apr 04 2012 14 56 57.366 218.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_054_triggered_Wed Apr 04 2012 14 57 02.357 345.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_055_triggered_Wed Apr 04 2012 14 57 07.348 471.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_056_triggered_Wed Apr 04 2012 14 57 12.339 597.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_057_triggered_Wed Apr 04 2012 14 57 17.330 724.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_058_triggered_Wed Apr 04 2012 14 57 22.321 850.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_059_triggered_Wed Apr 04 2012 14 57 27.312 976.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_060_triggered_Wed Apr 04 2012 14 57 32.304 103.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_061_triggered_Wed Apr 04 2012 14 57 37.295 229.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_062_triggered_Wed Apr 04 2012 14 57 42.286 356.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_NoSLN_063_triggered_Wed Apr 04 2012 14 57 47.277 482.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_128_triggered_Wed Apr 04 2012 15 10 19.579 253.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_129_triggered_Wed Apr 04 2012 15 10 24.570 380.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_130_triggered_Wed Apr 04 2012 15 10 29.561 506.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_131_triggered_Wed Apr 04 2012 15 10 34.552 632.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_132_triggered_Wed Apr 04 2012 15 10 39.543 759.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_133_triggered_Wed Apr 04 2012 15 10 44.534 885.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_134_triggered_Wed Apr 04 2012 15 10 49.526 011.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_135_triggered_Wed Apr 04 2012 15 10 54.517 137.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_136_triggered_Wed Apr 04 2012 15 10 59.508 264.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_137_triggered_Wed Apr 04 2012 15 11 04.499 390.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_138_triggered_Wed Apr 04 2012 15 11 09.490 516.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_139_triggered_Wed Apr 04 2012 15 11 14.481 643.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_140_triggered_Wed Apr 04 2012 15 11 19.472 769.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_141_triggered_Wed Apr 04 2012 15 11 24.463 895.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_142_triggered_Wed Apr 04 2012 15 11 29.455 022.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_143_triggered_Wed Apr 04 2012 15 11 34.446 148.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_144_triggered_Wed Apr 04 2012 15 11 39.437 274.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_145_triggered_Wed Apr 04 2012 15 11 44.428 401.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_146_triggered_Wed Apr 04 2012 15 11 49.419 527.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_147_triggered_Wed Apr 04 2012 15 11 54.410 653.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_148_triggered_Wed Apr 04 2012 15 11 59.401 780.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_149_triggered_Wed Apr 04 2012 15 12 04.392 906.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_150_triggered_Wed Apr 04 2012 15 12 09.384 032.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_151_triggered_Wed Apr 04 2012 15 12 14.375 159.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_152_triggered_Wed Apr 04 2012 15 12 19.366 285.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_153_triggered_Wed Apr 04 2012 15 12 24.357 411.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_154_triggered_Wed Apr 04 2012 15 12 29.348 538.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_155_triggered_Wed Apr 04 2012 15 12 34.339 664.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_156_triggered_Wed Apr 04 2012 15 12 39.330 791.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_157_triggered_Wed Apr 04 2012 15 12 44.321 917.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_158_triggered_Wed Apr 04 2012 15 12 49.313 043.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_159_triggered_Wed Apr 04 2012 15 12 54.304 169.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_160_triggered_Wed Apr 04 2012 15 12 59.295 296.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_161_triggered_Wed Apr 04 2012 15 13 04.286 422.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_162_triggered_Wed Apr 04 2012 15 13 09.277 548.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_163_triggered_Wed Apr 04 2012 15 13 14.268 675.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_164_triggered_Wed Apr 04 2012 15 13 19.259 801.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_165_triggered_Wed Apr 04 2012 15 13 24.250 927.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_166_triggered_Wed Apr 04 2012 15 13 29.242 054.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_167_triggered_Wed Apr 04 2012 15 13 34.233 180.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_168_triggered_Wed Apr 04 2012 15 13 39.224 306.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_169_triggered_Wed Apr 04 2012 15 13 44.215 433.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_170_triggered_Wed Apr 04 2012 15 13 49.206 559.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_171_triggered_Wed Apr 04 2012 15 13 54.197 686.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_172_triggered_Wed Apr 04 2012 15 13 59.188 812.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_173_triggered_Wed Apr 04 2012 15 14 04.179 938.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_174_triggered_Wed Apr 04 2012 15 14 09.171 065.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_175_triggered_Wed Apr 04 2012 15 14 14.162 191.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_176_triggered_Wed Apr 04 2012 15 14 19.153 317.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_177_triggered_Wed Apr 04 2012 15 14 24.144 444.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_178_triggered_Wed Apr 04 2012 15 14 29.135 570.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_179_triggered_Wed Apr 04 2012 15 14 34.126 696.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_180_triggered_Wed Apr 04 2012 15 14 39.117 823.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_181_triggered_Wed Apr 04 2012 15 14 44.108 949.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_182_triggered_Wed Apr 04 2012 15 14 49.100 076.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_183_triggered_Wed Apr 04 2012 15 14 54.091 202.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_184_triggered_Wed Apr 04 2012 15 14 59.082 328.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_185_triggered_Wed Apr 04 2012 15 15 04.073 455.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_186_triggered_Wed Apr 04 2012 15 15 09.064 581.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_187_triggered_Wed Apr 04 2012 15 15 14.055 708.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_188_triggered_Wed Apr 04 2012 15 15 19.046 834.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_189_triggered_Wed Apr 04 2012 15 15 24.037 961.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_190_triggered_Wed Apr 04 2012 15 15 29.029 087.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition02_191_triggered_Wed Apr 04 2012 15 15 34.020 214.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_192_triggered_Wed Apr 04 2012 15 17 40.319 069.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_193_triggered_Wed Apr 04 2012 15 17 45.310 196.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_194_triggered_Wed Apr 04 2012 15 17 50.301 322.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_195_triggered_Wed Apr 04 2012 15 17 55.292 449.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_196_triggered_Wed Apr 04 2012 15 18 00.283 575.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_197_triggered_Wed Apr 04 2012 15 18 05.274 702.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_198_triggered_Wed Apr 04 2012 15 18 10.265 828.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_199_triggered_Wed Apr 04 2012 15 18 15.256 955.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_200_triggered_Wed Apr 04 2012 15 18 20.248 081.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_201_triggered_Wed Apr 04 2012 15 18 25.239 208.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_202_triggered_Wed Apr 04 2012 15 18 30.230 334.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_203_triggered_Wed Apr 04 2012 15 18 35.221 461.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_204_triggered_Wed Apr 04 2012 15 18 40.212 587.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_205_triggered_Wed Apr 04 2012 15 18 45.203 714.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_206_triggered_Wed Apr 04 2012 15 18 50.194 840.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_207_triggered_Wed Apr 04 2012 15 18 55.185 967.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_208_triggered_Wed Apr 04 2012 15 19 00.177 093.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_209_triggered_Wed Apr 04 2012 15 19 05.168 220.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_210_triggered_Wed Apr 04 2012 15 19 10.159 346.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_211_triggered_Wed Apr 04 2012 15 19 15.150 473.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_212_triggered_Wed Apr 04 2012 15 19 20.141 599.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_213_triggered_Wed Apr 04 2012 15 19 25.132 726.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_214_triggered_Wed Apr 04 2012 15 19 30.123 852.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_215_triggered_Wed Apr 04 2012 15 19 35.114 979.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_216_triggered_Wed Apr 04 2012 15 19 40.106 105.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_217_triggered_Wed Apr 04 2012 15 19 45.097 232.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_218_triggered_Wed Apr 04 2012 15 19 50.088 358.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_219_triggered_Wed Apr 04 2012 15 19 55.079 485.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_220_triggered_Wed Apr 04 2012 15 20 00.070 611.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_221_triggered_Wed Apr 04 2012 15 20 05.061 738.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_222_triggered_Wed Apr 04 2012 15 20 10.052 864.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_223_triggered_Wed Apr 04 2012 15 20 15.043 991.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_224_triggered_Wed Apr 04 2012 15 20 20.035 117.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_225_triggered_Wed Apr 04 2012 15 20 25.026 244.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_226_triggered_Wed Apr 04 2012 15 20 30.017 370.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_227_triggered_Wed Apr 04 2012 15 20 35.008 497.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_228_triggered_Wed Apr 04 2012 15 20 39.999 623.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_229_triggered_Wed Apr 04 2012 15 20 44.990 750.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_230_triggered_Wed Apr 04 2012 15 20 49.981 876.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_231_triggered_Wed Apr 04 2012 15 20 54.973 003.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_232_triggered_Wed Apr 04 2012 15 20 59.964 129.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_233_triggered_Wed Apr 04 2012 15 21 04.955 256.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_234_triggered_Wed Apr 04 2012 15 21 09.946 382.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_235_triggered_Wed Apr 04 2012 15 21 14.937 509.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_236_triggered_Wed Apr 04 2012 15 21 19.928 636.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_237_triggered_Wed Apr 04 2012 15 21 24.919 762.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_238_triggered_Wed Apr 04 2012 15 21 29.910 889.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_239_triggered_Wed Apr 04 2012 15 21 34.902 015.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_240_triggered_Wed Apr 04 2012 15 21 39.893 142.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_241_triggered_Wed Apr 04 2012 15 21 44.884 268.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_242_triggered_Wed Apr 04 2012 15 21 49.875 395.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_243_triggered_Wed Apr 04 2012 15 21 54.866 522.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_244_triggered_Wed Apr 04 2012 15 21 59.857 648.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_245_triggered_Wed Apr 04 2012 15 22 04.848 775.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_246_triggered_Wed Apr 04 2012 15 22 09.839 901.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_247_triggered_Wed Apr 04 2012 15 22 14.831 028.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_248_triggered_Wed Apr 04 2012 15 22 19.822 155.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_249_triggered_Wed Apr 04 2012 15 22 24.813 281.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_250_triggered_Wed Apr 04 2012 15 22 29.804 408.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_251_triggered_Wed Apr 04 2012 15 22 34.795 534.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_252_triggered_Wed Apr 04 2012 15 22 39.786 661.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_253_triggered_Wed Apr 04 2012 15 22 44.777 787.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_254_triggered_Wed Apr 04 2012 15 22 49.768 914.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_SLN_condition03_255_triggered_Wed Apr 04 2012 15 22 54.760 041.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_064_triggered_Wed Apr 04 2012 14 59 48.340 672.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_065_triggered_Wed Apr 04 2012 14 59 53.331 798.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_066_triggered_Wed Apr 04 2012 14 59 58.322 925.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_067_triggered_Wed Apr 04 2012 15 00 03.314 051.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_068_triggered_Wed Apr 04 2012 15 00 08.305 177.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_069_triggered_Wed Apr 04 2012 15 00 13.296 304.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_070_triggered_Wed Apr 04 2012 15 00 18.287 430.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_071_triggered_Wed Apr 04 2012 15 00 23.278 556.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_072_triggered_Wed Apr 04 2012 15 00 28.269 683.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_073_triggered_Wed Apr 04 2012 15 00 33.260 809.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_074_triggered_Wed Apr 04 2012 15 00 38.251 936.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_075_triggered_Wed Apr 04 2012 15 00 43.243 062.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_076_triggered_Wed Apr 04 2012 15 00 48.234 188.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_077_triggered_Wed Apr 04 2012 15 00 53.225 315.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_078_triggered_Wed Apr 04 2012 15 00 58.216 441.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_079_triggered_Wed Apr 04 2012 15 01 03.207 567.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_080_triggered_Wed Apr 04 2012 15 01 08.198 694.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_081_triggered_Wed Apr 04 2012 15 01 13.189 820.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_082_triggered_Wed Apr 04 2012 15 01 18.180 946.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_083_triggered_Wed Apr 04 2012 15 01 23.172 073.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_084_triggered_Wed Apr 04 2012 15 01 28.163 199.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_085_triggered_Wed Apr 04 2012 15 01 33.154 325.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_086_triggered_Wed Apr 04 2012 15 01 38.145 452.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_087_triggered_Wed Apr 04 2012 15 01 43.136 578.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_088_triggered_Wed Apr 04 2012 15 01 48.127 704.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_089_triggered_Wed Apr 04 2012 15 01 53.118 831.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_090_triggered_Wed Apr 04 2012 15 01 58.109 957.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_091_triggered_Wed Apr 04 2012 15 02 03.101 083.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_092_triggered_Wed Apr 04 2012 15 02 08.092 210.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_093_triggered_Wed Apr 04 2012 15 02 13.083 336.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_094_triggered_Wed Apr 04 2012 15 02 18.074 463.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_095_triggered_Wed Apr 04 2012 15 02 23.065 589.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_096_triggered_Wed Apr 04 2012 15 02 28.056 715.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_097_triggered_Wed Apr 04 2012 15 02 33.047 842.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_098_triggered_Wed Apr 04 2012 15 02 38.038 968.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_099_triggered_Wed Apr 04 2012 15 02 43.030 094.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_100_triggered_Wed Apr 04 2012 15 02 48.021 221.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_101_triggered_Wed Apr 04 2012 15 02 53.012 347.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_102_triggered_Wed Apr 04 2012 15 02 58.003 473.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_103_triggered_Wed Apr 04 2012 15 03 02.994 600.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_104_triggered_Wed Apr 04 2012 15 03 07.985 726.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_105_triggered_Wed Apr 04 2012 15 03 12.976 853.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_106_triggered_Wed Apr 04 2012 15 03 17.967 979.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_107_triggered_Wed Apr 04 2012 15 03 22.959 105.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_108_triggered_Wed Apr 04 2012 15 03 27.950 232.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_109_triggered_Wed Apr 04 2012 15 03 32.941 358.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_110_triggered_Wed Apr 04 2012 15 03 37.932 485.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_111_triggered_Wed Apr 04 2012 15 03 42.923 611.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_112_triggered_Wed Apr 04 2012 15 03 47.914 737.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_113_triggered_Wed Apr 04 2012 15 03 52.905 864.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_114_triggered_Wed Apr 04 2012 15 03 57.896 990.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_115_triggered_Wed Apr 04 2012 15 04 02.888 116.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_116_triggered_Wed Apr 04 2012 15 04 07.879 243.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_117_triggered_Wed Apr 04 2012 15 04 12.870 369.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_118_triggered_Wed Apr 04 2012 15 04 17.861 496.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_119_triggered_Wed Apr 04 2012 15 04 22.852 622.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_120_triggered_Wed Apr 04 2012 15 04 27.843 748.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_121_triggered_Wed Apr 04 2012 15 04 32.834 875.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_122_triggered_Wed Apr 04 2012 15 04 37.826 001.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_123_triggered_Wed Apr 04 2012 15 04 42.817 128.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_124_triggered_Wed Apr 04 2012 15 04 47.808 254.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_125_triggered_Wed Apr 04 2012 15 04 52.799 380.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_126_triggered_Wed Apr 04 2012 15 04 57.790 507.001.strain_onset.npz',
#  '/extra/InVivoDog/python/cine/results_save/04_04_2012_asymmetricRLN/asymmetricRLN_ThresholdSLN_condition01_127_triggered_Wed Apr 04 2012 15 05 02.781 633.001.strain_onset.npz']

# %%
def distances(clickdata):
    # baseline vectors between anterior landmark and VP on left and right sides
    vlr_clickdata = clickdata[1:] - clickdata[0]
    # vector between left and right VPs
    dx_clickdata = clickdata[1] - clickdata[2]
    
    # baseline lengths
    l_clickdata = np.hypot(vlr_clickdata[:, 0], vlr_clickdata[:, 1])
    d_clickdata = np.hypot(dx_clickdata[0], dx_clickdata[1])
    
    return l_clickdata, d_clickdata

# %%
strains = {}

for SLNnum, SLNcond in enumerate(SLNconditions):
    strains[ SLNcond ] = []

    SLNcond_name = datafiles[SLNcond].split('Wed')[0].replace(' ', '_')
    print "SLNcond_name, SLNnum: ", (SLNcond_name, SLNnum)

    SLNcond_landmarkfiles = sorted(
        [item for item in clickfiles if os.path.basename(item).startswith(SLNcond_name)])
    
    # debugging:
    # strains[SLNcond] = SLNcond_landmarkfiles

    for clickfile in SLNcond_landmarkfiles:
        data = np.load(clickfile)

        if data['TAconditionindex'] != SLNnum:
            print "Error: wrong SLN condition index"
            continue

        baseline = data['baseline_pos']
        if len(baseline) < 3:
            print "ERROR: baseline: #clicks < 3: ", clickfile
            strains.append([np.nan, np.nan, np.nan])
            continue
            
        onset = data['onset_pos']
        if len(onset) < 3:
            print "ERROR: onset: #clicks < 3: ", clickfile
            strains.append([np.nan, np.nan, np.nan])
            continue

        l_baseline, d_baseline = distances(baseline)
        l_onset, d_onset = distances(onset)

        leftstrain, rightstrain = (l_onset - l_baseline) / l_baseline * 100.0
        # dVPrel = (d_onset - d_baseline) / d_baseline * 100.0
        dVPrel = d_onset / d_baseline * 100.0

        strains[ SLNcond ].append([leftstrain, rightstrain, dVPrel])
# Out:
# SLNcond_name, SLNnum:  ('asymmetricRLN_NoSLN_', 0)
# SLNcond_name, SLNnum:
#  ('asymmetricRLN_ThresholdSLN_condition01_', 1)
# SLNcond_name, SLNnum:
#  ('asymmetricRLN_SLN_condition02_', 2)
# SLNcond_name, SLNnum:
#  ('asymmetricRLN_SLN_condition03_', 3)
# SLNcond_name, SLNnum:
#  ('asymmetricRLN_MaxSLN_condition04_', 4)

# %%
Nlevels = dogdata.Nlevels
print dogdata.nervenamelist
# need left RLN versus right RLN
rellevels = dogdata.a_rellevels[:, [2, 3]]
# dogdata.a_rellevels
# Out:
# ['left SLN', 'right SLN', 'left RLN', 'right RLN', 'left TA', 'right TA']

# %%
# var_strings and data_vars need to be sorted in the same way
# maybe better: [('F0', a_F0), ('ps', ps_onset), ('Q', Q_onset), ('A', A_onset), ('lstrain', None), ('rstrain', None), ('dVP', None)]
var_strings = ['F0', 'ps', 'Q', 'A', 'lstrain', 'rstrain', 'dVP']
data_vars   = [a_F0, ps_onset, Q_onset, A_onset]

# No Phonation conditions
np_strings = ['ps', 'Q', 'A', 'lstrain', 'rstrain', 'dVP']
data_np    = [ps_noonset, Q_noonset, A_noonset]

# %%
var_plot = dict()
var_np_plot = dict()

for var in var_strings:
    var_plot[var] = np.nan * np.ones( (Nlevels, Nlevels, len(SLNconditions) ) ) # leftRLNlevel, rightRLNlevel, SLNlevel
    
for var in np_strings:
    var_np_plot[var] = np.nan * np.ones( (Nlevels, Nlevels, len(SLNconditions) ) )

# %%
coord_plot = dict()

coord_strings = ['left RLN', 'right RLN', 'SLN']

for coord in coord_strings:
    coord_plot[coord] = np.nan * np.ones( (Nlevels, Nlevels, len(SLNconditions) ) )

for SLNnum, SLNcond in enumerate(SLNconditions):
    coord_plot['SLN'][:, :, SLNnum] = SLNnum

    for stimind, (leftRLNlevel, rightRLNlevel) in enumerate(rellevels):
        # leftRLN: row index, i.e. y-axis in plot
        # rightRLN: column index, i.e. x-axis in plot
        
        coord_plot['left RLN'][leftRLNlevel, rightRLNlevel, SLNnum] = leftRLNlevel
        coord_plot['right RLN'][leftRLNlevel, rightRLNlevel, SLNnum] = rightRLNlevel

# %%
for SLNnum, SLNcond in enumerate(SLNconditions):

    for stimind, (leftRLNlevel, rightRLNlevel) in enumerate(rellevels):
        # leftRLN: row index, i.e. y-axis in plot
        # rightRLN: column index, i.e. x-axis in plot
        
        for var, dat in zip(var_strings, data_vars):
            var_plot[var][leftRLNlevel, rightRLNlevel, SLNnum] = dat[stimind, SLNnum]
            
        # e.g.: F0_plot[SLNcond][leftRLNlevel, rightRLNlevel] = a_F0[stimind, SLNnum]
        
        for var, dat in zip(np_strings, data_np):
            var_np_plot[var][leftRLNlevel, rightRLNlevel, SLNnum] = dat[stimind, SLNnum]

        # last three variables: lstrain, rstrain, dVP
        for varnum, var in enumerate(var_strings[-3:]):
            var_plot[var][leftRLNlevel, rightRLNlevel, SLNnum] = strains[SLNcond][stimind][varnum]
        
        # e.g.: lstrain_plot[TAcond][SLNlevel, RLNlevel] = strains[SLNcond][stimind][0]

            if np.isnan(var_plot['F0'][leftRLNlevel, rightRLNlevel, SLNnum]):
                var_plot[var][leftRLNlevel, rightRLNlevel, SLNnum] = np.nan
                # e.g.: lstrain_plot[TAcond][SLNlevel, RLNlevel] = np.nan
                
                var_np_plot[var][leftRLNlevel, rightRLNlevel, SLNnum] = strains[SLNcond][stimind][varnum]

# %%
var_plot.keys()
# Out:
# ['F0', 'ps', 'lstrain', 'Q', 'A', 'rstrain', 'dVP']

# %%
var_labels = ['onset frequency [Hz]', 'onset pressure [Pa]', 'onset flow rate [ml/s]', 'onset Bernoulli area [a.u.]',
              'left strain [%]', 'right strain [%]', 'Dvp [%]']

label_dict = dict(zip(var_strings, var_labels))
label_dict
# Out:
# {'A': 'onset Bernoulli area [a.u.]',
#  'F0': 'onset frequency [Hz]',
#  'Q': 'onset flow rate [ml/s]',
#  'dVP': 'Dvp [%]',
#  'lstrain': 'left strain [%]',
#  'ps': 'onset pressure [Pa]',
#  'rstrain': 'right strain [%]'}

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
coord_plot.keys()
# Out:
# ['SLN', 'left RLN', 'right RLN']

# %%
# help Axes3D.scatter

# %%
# help a.contourf3D

# %%
f = plt.figure()

a = f.add_subplot(111, projection = '3d')

aa = a.scatter(coord_plot['left RLN'].ravel(), coord_plot['right RLN'].ravel(), coord_plot['SLN'].ravel(),
          s = var_plot['F0'].ravel()**2 * 0.01,
          c = var_plot['F0'].ravel(),
          # alpha = 0.8, 
          edgecolors = 'None', cmap = cmap)

a.set_xlabel('left RLN')
a.set_ylabel('right RLN')
a.set_zlabel('SLN')

plt.colorbar(aa)

plt.show()

# %%
def make_left_right_plot(plotvar = 'F0', uniformscale = True, savefigure = False, showfigure = False, figsize = (15, 12)):
    if figsize == None:
        figsize = mpl.rcParams['figure.figsize']

    colorbarlabel = label_dict[plotvar]

    for SLNnum, SLNcond in enumerate(SLNconditions):
        fig, ax = plt.subplots(figsize = figsize)

        ax.set_title(SLNcond)

        axim = ax.imshow(var_plot[plotvar][:, :, SLNnum])

        # scale all axis with respect to global min and max
        # uniform_scale = False
        if uniformscale:
            axim.set_clim(np.nanmin(var_plot[plotvar]), np.nanmax(var_plot[plotvar]))
            ax.relim()

        co = ax.contour(axim.get_array(), 
                        6, 
                        colors = 'w')
        ax.clabel(co, fmt = '%.0f', fontsize = 10, inline = True)

        ax.axis([-0.5, 7.5, -0.5, 7.5])

        ax.set_ylabel('left RLN')

        ax.grid(False)

        if True or SLNnum == 0:
            cb = fig.colorbar(axim, ax = ax)
            cb.set_label(colorbarlabel)

        if True or SLNcond == SLNconditions[-1]:
            ax.set_xlabel('right RLN')

        figname = "left-rightRLN.%s.%s.pdf" % ( plotvar, SLNcond.replace(' ', '_') )

        if uniformscale:
            figname = figname.replace('.pdf', '.normalized.pdf')

        if savefigure:
            print "saving: ", figname
            fig.savefig(figname, orientation = 'landscape',
                        papertype = 'letter', format = 'pdf',
                        bbox_inches = 'tight', pad_inches = 0.1)


    if showfigure:
        plt.show()
    else:
        plt.close('all')

# %%
var_strings
# Out:
# ['F0', 'ps', 'Q', 'A', 'lstrain', 'rstrain', 'dVP']

# %%
make_left_right_plot(plotvar = 'F0', uniformscale = False, savefigure = False, showfigure = True)
# Out:
# saving:  left-rightRLN.F0.SLN_0.pdf
# saving:
#  left-rightRLN.F0.SLN_1.pdf
# saving:
#  left-rightRLN.F0.SLN_2.pdf
# saving:
#  left-rightRLN.F0.SLN_3.pdf
# saving:
#  left-rightRLN.F0.SLN_4.pdf

# %%
for plotvar in var_strings:
    make_left_right_plot(plotvar = plotvar, uniformscale = False, savefigure = True, showfigure = False)
    make_left_right_plot(plotvar = plotvar, uniformscale = True, savefigure = True, showfigure = False)
# Out:
# saving:  left-rightRLN.F0.SLN_0.pdf
# saving:
#  left-rightRLN.F0.SLN_1.pdf
# saving:
#  left-rightRLN.F0.SLN_2.pdf
# saving:
#  left-rightRLN.F0.SLN_3.pdf
# saving:
#  left-rightRLN.F0.SLN_4.pdf
# saving:
#  left-rightRLN.F0.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.F0.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.F0.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.F0.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.F0.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.ps.SLN_0.pdf
# saving:
#  left-rightRLN.ps.SLN_1.pdf
# saving:
#  left-rightRLN.ps.SLN_2.pdf
# saving:
#  left-rightRLN.ps.SLN_3.pdf
# saving:
#  left-rightRLN.ps.SLN_4.pdf
# saving:
#  left-rightRLN.ps.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.ps.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.ps.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.ps.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.ps.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.Q.SLN_0.pdf
# saving:
#  left-rightRLN.Q.SLN_1.pdf
# saving:
#  left-rightRLN.Q.SLN_2.pdf
# saving:
#  left-rightRLN.Q.SLN_3.pdf
# saving:
#  left-rightRLN.Q.SLN_4.pdf
# saving:
#  left-rightRLN.Q.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.Q.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.Q.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.Q.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.Q.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.A.SLN_0.pdf
# saving:
#  left-rightRLN.A.SLN_1.pdf
# saving:
#  left-rightRLN.A.SLN_2.pdf
# saving:
#  left-rightRLN.A.SLN_3.pdf
# saving:
#  left-rightRLN.A.SLN_4.pdf
# saving:
#  left-rightRLN.A.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.A.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.A.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.A.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.A.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.lstrain.SLN_0.pdf
# saving:
#  left-rightRLN.lstrain.SLN_1.pdf
# saving:
#  left-rightRLN.lstrain.SLN_2.pdf
# saving:
#  left-rightRLN.lstrain.SLN_3.pdf
# saving:
#  left-rightRLN.lstrain.SLN_4.pdf
# saving:
#  left-rightRLN.lstrain.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.lstrain.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.lstrain.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.lstrain.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.lstrain.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.rstrain.SLN_0.pdf
# saving:
#  left-rightRLN.rstrain.SLN_1.pdf
# saving:
#  left-rightRLN.rstrain.SLN_2.pdf
# saving:
#  left-rightRLN.rstrain.SLN_3.pdf
# saving:
#  left-rightRLN.rstrain.SLN_4.pdf
# saving:
#  left-rightRLN.rstrain.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.rstrain.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.rstrain.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.rstrain.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.rstrain.SLN_4.normalized.pdf
# saving:
#  left-rightRLN.dVP.SLN_0.pdf
# saving:
#  left-rightRLN.dVP.SLN_1.pdf
# saving:
#  left-rightRLN.dVP.SLN_2.pdf
# saving:
#  left-rightRLN.dVP.SLN_3.pdf
# saving:
#  left-rightRLN.dVP.SLN_4.pdf
# saving:
#  left-rightRLN.dVP.SLN_0.normalized.pdf
# saving:
#  left-rightRLN.dVP.SLN_1.normalized.pdf
# saving:
#  left-rightRLN.dVP.SLN_2.normalized.pdf
# saving:
#  left-rightRLN.dVP.SLN_3.normalized.pdf
# saving:
#  left-rightRLN.dVP.SLN_4.normalized.pdf

# %%
import subprocess, shlex

# %%
cmd = 'pdftk left-rightRLN.%s.SLN_?.pdf cat output left-rightRLN.%s.SLN_01234.pdf' % ((plotvar, ) * 2)
print shlex.split(cmd)
# Out:
# ['pdftk', 'left-rightRLN.F0.SLN_?.pdf', 'cat', 'output', 'left-rightRLN.F0.SLN_01234.pdf']

# %%
subprocess.check_output(cmd, shell = True)
# Out:
# 0

# %%
try:
    subprocess.check_output(shlex.split(cmd), stderr = subprocess.STDOUT)
except subprocess.CalledProcessError as err:
    print err.output
# Out:
# Error: Failed to open PDF file:
#    left-rightRLN.F0.SLN_?.pdf
# Errors encountered.  No output created.
# Done.  Input errors, so no output created.

# %%
" ".join( sorted(glob.glob('left-rightRLN.%s.SLN_?.pdf' % plotvar)) )
# Out:
# 'left-rightRLN.dVP.SLN_0.pdf left-rightRLN.dVP.SLN_1.pdf left-rightRLN.dVP.SLN_2.pdf left-rightRLN.dVP.SLN_3.pdf left-rightRLN.dVP.SLN_4.pdf'

# %%
for plotvar in var_strings:
    cmd = "pdftk left-rightRLN.%s.SLN_?.pdf cat output left-rightRLN.%s.SLN_01234.pdf" % ((plotvar, ) * 2)
    print cmd
    
    r = subprocess.check_output(cmd, shell = True)
    
    cmd = cmd.replace('.pdf', '.normalized.pdf')
    print cmd
    
    r = subprocess.check_output(cmd, shell = True)
# Out:
# pdftk left-rightRLN.F0.SLN_?.pdf cat output left-rightRLN.F0.SLN_01234.pdf
# pdftk left-rightRLN.F0.SLN_?.normalized.pdf cat output left-rightRLN.F0.SLN_01234.normalized.pdf
# pdftk left-rightRLN.ps.SLN_?.pdf cat output left-rightRLN.ps.SLN_01234.pdf
# pdftk left-rightRLN.ps.SLN_?.normalized.pdf cat output left-rightRLN.ps.SLN_01234.normalized.pdf
# pdftk left-rightRLN.Q.SLN_?.pdf cat output left-rightRLN.Q.SLN_01234.pdf
# pdftk left-rightRLN.Q.SLN_?.normalized.pdf cat output left-rightRLN.Q.SLN_01234.normalized.pdf
# pdftk left-rightRLN.A.SLN_?.pdf cat output left-rightRLN.A.SLN_01234.pdf
# pdftk left-rightRLN.A.SLN_?.normalized.pdf cat output left-rightRLN.A.SLN_01234.normalized.pdf
# pdftk left-rightRLN.lstrain.SLN_?.pdf cat output left-rightRLN.lstrain.SLN_01234.pdf
# pdftk left-rightRLN.lstrain.SLN_?.normalized.pdf cat output left-rightRLN.lstrain.SLN_01234.normalized.pdf
# pdftk left-rightRLN.rstrain.SLN_?.pdf cat output left-rightRLN.rstrain.SLN_01234.pdf
# pdftk left-rightRLN.rstrain.SLN_?.normalized.pdf cat output left-rightRLN.rstrain.SLN_01234.normalized.pdf
# pdftk left-rightRLN.dVP.SLN_?.pdf cat output left-rightRLN.dVP.SLN_01234.pdf
# pdftk left-rightRLN.dVP.SLN_?.normalized.pdf cat output left-rightRLN.dVP.SLN_01234.normalized.pdf

# %%
def make_rightRLN_SLN_plot(plotvar = 'F0', uniformscale = True, savefigure = False, showfigure = False, figsize = (15, 12)):
    if figsize == None:
        figsize = mpl.rcParams['figure.figsize']

    colorbarlabel = label_dict[plotvar]

    for leftRLNnum in range(Nlevels):
        fig, ax = plt.subplots(figsize = figsize)
        
        leftRLNcond = 'left RLN %d' % leftRLNnum
        
        ax.set_title(leftRLNcond)
        
        axim = ax.imshow(var_plot[plotvar][leftRLNnum, :, :])
        
        # scale all axis with respect to global min and max
        # uniform_scale = False
        if uniformscale:
            axim.set_clim(np.nanmin(var_plot[plotvar]), np.nanmax(var_plot[plotvar]))
            ax.relim()
        
        co = ax.contour(axim.get_array(), 
                        6, 
                        colors = 'w')
        ax.clabel(co, fmt = '%.0f', fontsize = 10, inline = True)
        
        ax.axis([-0.5, 4.5, -0.5, 7.5])
        
        ax.set_ylabel('right RLN')
        
        ax.grid(False)
        
        if True or leftRLNnum == 0:
            cb = fig.colorbar(axim, ax = ax)
            cb.set_label(colorbarlabel)
        
        if True or leftRLNnum == Nlevels - 1:
            ax.set_xlabel('SLN')
        
        figname = "rightRLN-SLN.%s.%s.pdf" % ( plotvar, leftRLNcond.replace(' ', '_') )

        if uniformscale:
            figname = figname.replace('.pdf', '.normalized.pdf')

        if savefigure:
            print "saving: ", figname
        
            fig.savefig(figname, orientation = 'landscape',
                        papertype = 'letter', format = 'pdf',
                        bbox_inches = 'tight', pad_inches = 0.1)
    if showfigure:
        plt.show()
    else:
        plt.close('all')

# %%
for plotvar in var_strings:
    make_rightRLN_SLN_plot(plotvar = plotvar, uniformscale = False, savefigure = True, showfigure = False)
    make_rightRLN_SLN_plot(plotvar = plotvar, uniformscale = True, savefigure = True, showfigure = False)
# Out:
# saving:  rightRLN-SLN.F0.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.F0.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.ps.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.Q.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.A.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.lstrain.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.rstrain.left_RLN_7.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_0.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_1.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_2.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_3.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_4.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_5.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_6.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_7.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_0.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_1.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_2.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_3.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_4.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_5.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_6.normalized.pdf
# saving:
#  rightRLN-SLN.dVP.left_RLN_7.normalized.pdf

# %%
for plotvar in var_strings:
    cmd = "pdftk rightRLN-SLN.%s.left_RLN_?.pdf cat output rightRLN-SLN.%s.left_RLN_01234567.pdf" % ((plotvar, ) * 2)
    print cmd
    
    r = subprocess.check_output(cmd, shell = True)
    
    cmd = cmd.replace('.pdf', '.normalized.pdf')
    print cmd
    
    r = subprocess.check_output(cmd, shell = True)
# Out:
# pdftk rightRLN-SLN.F0.left_RLN_?.pdf cat output rightRLN-SLN.F0.left_RLN_01234.pdf
# pdftk rightRLN-SLN.F0.left_RLN_?.normalized.pdf cat output rightRLN-SLN.F0.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.ps.left_RLN_?.pdf cat output rightRLN-SLN.ps.left_RLN_01234.pdf
# pdftk rightRLN-SLN.ps.left_RLN_?.normalized.pdf cat output rightRLN-SLN.ps.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.Q.left_RLN_?.pdf cat output rightRLN-SLN.Q.left_RLN_01234.pdf
# pdftk rightRLN-SLN.Q.left_RLN_?.normalized.pdf cat output rightRLN-SLN.Q.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.A.left_RLN_?.pdf cat output rightRLN-SLN.A.left_RLN_01234.pdf
# pdftk rightRLN-SLN.A.left_RLN_?.normalized.pdf cat output rightRLN-SLN.A.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.lstrain.left_RLN_?.pdf cat output rightRLN-SLN.lstrain.left_RLN_01234.pdf
# pdftk rightRLN-SLN.lstrain.left_RLN_?.normalized.pdf cat output rightRLN-SLN.lstrain.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.rstrain.left_RLN_?.pdf cat output rightRLN-SLN.rstrain.left_RLN_01234.pdf
# pdftk rightRLN-SLN.rstrain.left_RLN_?.normalized.pdf cat output rightRLN-SLN.rstrain.left_RLN_01234.normalized.pdf
# pdftk rightRLN-SLN.dVP.left_RLN_?.pdf cat output rightRLN-SLN.dVP.left_RLN_01234.pdf
# pdftk rightRLN-SLN.dVP.left_RLN_?.normalized.pdf cat output rightRLN-SLN.dVP.left_RLN_01234.normalized.pdf

# %%
mpl.rcParams['figure.figsize'] = (10, 8)

# %%
plt.plot(var_plot['lstrain'].ravel(), var_plot['rstrain'].ravel(), 'r.', zorder = 10)
plt.plot([-15, 35], [-15, 35], 'k', zorder = 1, alpha = 0.5)
plt.axis([-15, 35, -15, 35])

plt.xlabel('left strain [%]')
plt.ylabel('right strain [%]')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex = 'col', sharey = 'col')

ax1.plot(var_plot['lstrain'].ravel(), var_plot['F0'].ravel(), 'r.', label = 'left strain')
# ax1.xlabel('left strain [%]')
ax1.set_ylabel('F0 [Hz]')
# ax1.xlim(xmin = -20, xmax = 40)

ax1.legend(fontsize = 'small', numpoints = 1, loc = 'upper left')

ax2.plot(var_plot['rstrain'].ravel(), var_plot['F0'].ravel(), 'r.', label = 'right strain')

ax2.set_xlabel('strain [%]')
ax2.set_ylabel('F0 [Hz]')
ax2.legend(fontsize = 'small', numpoints = 1, loc = 'upper left')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['lstrain'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 10, label = SLNcond, alpha = 0.6)

plt.plot(var_np_plot['lstrain'].ravel(), np.ones_like(var_np_plot['lstrain']).ravel() * 50, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('left strain [%]')
plt.ylabel('F0 [Hz]')

plt.xlim(xmin = -20, xmax = 40)
plt.ylim(ymin = 40, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

if True:
    figname = "left-rightRLN_F0-strain.pdf"
    fig.savefig(figname, orientation = 'landscape',
                papertype = 'letter', format = 'pdf',
                bbox_inches = 'tight', pad_inches = 0.1)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['rstrain'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 5, label = SLNcond)

plt.plot(var_np_plot['rstrain'].ravel(), np.ones_like(var_np_plot['rstrain']).ravel() * 50, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('right strain [%]')
plt.ylabel('F0 [Hz]')

plt.xlim(xmin = -20, xmax = 40)
plt.ylim(ymin = 40, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

plt.show()

# %%
def scatterplot(x, y, z = None, xlabel = None, ylabel = None, zlabel = None, figsize = (13, 8), savename = None):
    fig, ax = plt.subplots(figsize = figsize)
    
    if z is not None:
        z2 = (z.ravel() - np.nanmin(z.ravel()) + 50)**2
        z2shift = (z2 - np.nanmin(z2))
        size = z2shift / np.nanmax(z2shift) * 975 + 25
        
        color = z.ravel()
    else:
        size = 50
        color = 'red'
    
    a1 = ax.scatter(x.ravel(), y.ravel(), 
                    s = size, 
                    marker = 'o', alpha = 0.6, 
                    c = color, 
                    edgecolors = 'None', cmap = cmap)
    
    # a2 = ax.plot(var_np_plot['lstrain'].ravel(), var_np_plot['dVP'].ravel(), '*', 
    #               ms = 10, mec = 'black', mfc = 'None', label = 'no onset')

    if xlabel is not None:
        ax.set_xlabel(xlabel)
    if ylabel is not None:
        ax.set_ylabel(ylabel)

    if z is not None:
        cb = fig.colorbar(a1)
        
        if zlabel is not None:
            cb.set_label(zlabel)

    ax.set_xlim(xmin = 0.5 * np.nanmin(x.ravel()),
                xmax = 1.1 * np.nanmax(x.ravel()))
    
    ax.xaxis.get_major_formatter().set_powerlimits((0, 4))
    
    if savename is not None:
        figname = savename
        fig.savefig(figname, orientation = 'landscape',
                    papertype = 'letter', format = 'pdf',
                    bbox_inches = 'tight', pad_inches = 0.1)
        
    plt.show()

# %%
scatterplot(var_plot['dVP'] * var_plot['F0']**2, var_plot['ps'], z = var_plot['F0'],
            xlabel = 'Dvp * F0^2 [a. u.]', ylabel = 'ps [Pa]', zlabel = 'frequency [Hz]', savename = 'left-rightRLN_scaling.pdf')

# %%
fig, ax = plt.subplots(figsize = (13, 8))

SLNnum = 2

plt.scatter(var_plot['lstrain'][:, :, :].ravel(), var_plot['dVP'][:, :, :].ravel(), 
            s = var_plot['F0'][:, :, :].ravel()**2 * 0.01, 
            marker = 'o', alpha = 0.6,
            c = var_plot['F0'][:, :, :].ravel(), 
            edgecolors = 'None', cmap = cmap)

plt.xlabel('left strain [%]')
plt.ylabel('dVP [%]')

plt.plot(var_np_plot['lstrain'].ravel(), var_np_plot['dVP'].ravel(), '*', ms = 10, mec = 'black', mfc = 'None', label = 'no onset')

cb = plt.colorbar()
cb.set_label('frequency [Hz]')

plt.xlim(xmin = -20, xmax = 40)

plt.show()

# %%
scatterplot(var_plot['Q'], var_plot['ps'], z = var_plot['F0'], 
            xlabel = 'Q [ml/s]', ylabel = 'ps [Pa]', zlabel = 'frequency [Hz]')

# %%
fig, ax = plt.subplots(figsize = (13, 8))

plt.scatter(var_plot['Q'].ravel(), var_plot['ps'].ravel(),
            s = var_plot['F0'].ravel()**2 * 0.01, 
            marker = 'o', alpha = 0.6,
            c = var_plot['F0'].ravel(), edgecolors = 'None', cmap = cmap)

plt.plot(var_np_plot['Q'].ravel(), var_np_plot['ps'].ravel(), '*', ms = 10, mec = 'black', mfc = 'None', label = 'no onset')

plt.xlabel('Q [ml/s]')
plt.ylabel('ps [Pa]')

cb = plt.colorbar()
cb.set_label('frequency [Hz]')

plt.ylim(ymin = 150, ymax = 1100)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['ps'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 5, label = SLNcond)

plt.plot(var_np_plot['ps'].ravel(), np.ones_like(var_np_plot['ps']).ravel() * 25, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('onset pressure [Pa]')
plt.ylabel('F0 [Hz]')

plt.xlim(xmin = 150, xmax = 1100)
# plt.ylim(ymin = 45, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['Q'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 5, label = SLNcond)

plt.plot(var_np_plot['Q'].ravel(), np.ones_like(var_np_plot['Q']).ravel() * 25, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('onset flow rate [ml/s]')
plt.ylabel('F0 [Hz]')

# plt.xlim(xmin = -20, xmax = 35)
# plt.ylim(ymin = 45, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['dVP'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 5, label = SLNcond)

plt.plot(var_np_plot['dVP'].ravel(), np.ones_like(var_np_plot['dVP']).ravel() * 25, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('dVP [%]')
plt.ylabel('F0 [Hz]')

plt.xlim(xmin = 10, xmax = 110)
# plt.ylim(ymin = 45, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

plt.show()

# %%
plt.plot(var_plot['A'].ravel(), var_plot['F0'].ravel(), 'r.')
plt.xlabel('A [a.u.]')
plt.ylabel('F0 [Hz]')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):
    
    plt.plot(var_plot['A'][:, :, SLNnum].ravel(), var_plot['F0'][:, :, SLNnum].ravel(), 
             symblist[SLNnum], mec = colorlist[SLNnum], mfc = 'None', ms = 5, label = SLNcond)

plt.plot(var_np_plot['A'].ravel(), np.ones_like(var_np_plot['A']).ravel() * 25, 
         '|', mec = 'k', mfc = 'None', ms = 10, label = 'no onset')
    
plt.xlabel('A [a.u]')
plt.ylabel('F0 [Hz]')

plt.xlim(xmin = 10)
# plt.ylim(ymin = 45, ymax = 350)

plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), numpoints = 1)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

plt.scatter(var_plot['dVP'].ravel(), var_plot['A'].ravel(), 
            s = var_plot['F0'].ravel()**2 * 0.01, 
            marker = 'o', alpha = 0.6, 
            c = var_plot['F0'].ravel(), edgecolors = 'None', cmap = cmap)

plt.plot(var_np_plot['dVP'].ravel(), var_np_plot['A'].ravel(), '*', ms = 7, mec = 'black', mfc = 'None', label = 'no onset', zorder = 1)

plt.xlabel('dVP [%]')
plt.ylabel('A [a.u.]')

cb = plt.colorbar()
cb.set_label('frequency [Hz]')

plt.xlim(xmin = 10, xmax = 110)
plt.ylim(ymin = 15, ymax = 110)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

plt.scatter(var_plot['lstrain'].ravel(), var_plot['A'].ravel(), 
            s = var_plot['F0'].ravel()**2 * 0.01, 
            marker = 'o', alpha = 0.6, 
            c = var_plot['F0'].ravel(), edgecolors = 'None', cmap = cmap)

plt.plot(var_np_plot['lstrain'].ravel(), var_np_plot['A'].ravel(), '*', 
         ms = 7, mec = 'black', mfc = 'None', label = 'no onset', zorder = 1)

plt.xlabel('lstrain [%]')
plt.ylabel('A [a.u.]')

cb = plt.colorbar()
cb.set_label('frequency [Hz]')

plt.xlim(xmax = 40)
plt.ylim(ymin = 15, ymax = 110)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (13, 8))

for SLNnum, SLNcond in enumerate(SLNconditions):

    plt.scatter(var_plot['lstrain'][:, :, SLNnum].ravel(), var_plot['A'][:, :, SLNnum].ravel(),
                s = var_plot['F0'][:, :, SLNnum].ravel() * 0.4,
                marker = symblist[SLNnum], c = var_plot['F0'][:, :, SLNnum].ravel(), 
                facecolors = 'None', 
                # edgecolors = 'None', 
                cmap = cmap,
                label = SLNcond)

plt.plot(var_np_plot['lstrain'].ravel(), var_np_plot['A'].ravel(), '*', ms = 7, mec = 'black', mfc = 'None', label = 'no onset', zorder = 1)

plt.xlabel('lstrain [%]')
plt.ylabel('A [a.u.]')

cb = plt.colorbar()
cb.set_label('frequency [Hz]')

plt.xlim(xmax = 40)
plt.ylim(ymin = 15, ymax = 110)

plt.legend(loc = 'upper left', bbox_to_anchor = (1.2, 1), numpoints = 1)

plt.show()
